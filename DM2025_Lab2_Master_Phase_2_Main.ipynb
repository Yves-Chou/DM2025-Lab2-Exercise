# %%
from google.colab import userdata
api_key = userdata.get('GOOGLE_API_KEY')
print(api_key)
# Out:
# AIzaSyCPfnuHc7yyNAEyhVSc1qashJ5Nz2b_P9w

# %% [markdown]
# # **Colab Environment Setup**

# %%
# Clone Lab 2's github repository to get all of our material first

# !git clone https://github.com/difersalest/DM2025-Lab2-Exercise.git
# Out:
# fatal: destination path 'DM2025-Lab2-Exercise' already exists and is not an empty directory.

# %%
# Installing all of our dependencies
# The lab in colab was tested with this, and everything should work as intended
# If in your case something is not working please notify the TAs
# !pip3 install python-dotenv==1.1.1 google-genai==1.33.0 langextract==1.0.9 langchain==0.3.27 langchain_community==0.3.29 langchain_core==0.3.75 langchain-google-genai==2.1.10 beautifulsoup4==4.13.5 chromadb==1.0.20 gradio==5.44.1 jupyter==1.1.1 scikit-learn==1.7.1 pandas==2.3.2 numpy==1.26.4 matplotlib==3.10.6 plotly==6.3.0 seaborn==0.13.2 nltk==3.9.1 umap-learn==0.5.9.post2 pymupdf==1.26.4
# Out:
# Requirement already satisfied: python-dotenv==1.1.1 in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: google-genai==1.33.0 in /usr/local/lib/python3.12/dist-packages (1.33.0)
# Requirement already satisfied: langextract==1.0.9 in /usr/local/lib/python3.12/dist-packages (1.0.9)
# Requirement already satisfied: langchain==0.3.27 in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: langchain_community==0.3.29 in /usr/local/lib/python3.12/dist-packages (0.3.29)
# Requirement already satisfied: langchain_core==0.3.75 in /usr/local/lib/python3.12/dist-packages (0.3.75)
# Requirement already satisfied: langchain-google-genai==2.1.10 in /usr/local/lib/python3.12/dist-packages (2.1.10)
# Requirement already satisfied: beautifulsoup4==4.13.5 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: chromadb==1.0.20 in /usr/local/lib/python3.12/dist-packages (1.0.20)
# Requirement already satisfied: gradio==5.44.1 in /usr/local/lib/python3.12/dist-packages (5.44.1)
# Requirement already satisfied: jupyter==1.1.1 in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: scikit-learn==1.7.1 in /usr/local/lib/python3.12/dist-packages (1.7.1)
# Requirement already satisfied: pandas==2.3.2 in /usr/local/lib/python3.12/dist-packages (2.3.2)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib==3.10.6 in /usr/local/lib/python3.12/dist-packages (3.10.6)
# Requirement already satisfied: plotly==6.3.0 in /usr/local/lib/python3.12/dist-packages (6.3.0)
# Requirement already satisfied: seaborn==0.13.2 in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: nltk==3.9.1 in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: umap-learn==0.5.9.post2 in /usr/local/lib/python3.12/dist-packages (0.5.9.post2)
# Requirement already satisfied: pymupdf==1.26.4 in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai==1.33.0) (4.11.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-genai==1.33.0) (2.38.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai==1.33.0) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai==1.33.0) (2.11.10)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai==1.33.0) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai==1.33.0) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai==1.33.0) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai==1.33.0) (4.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langextract==1.0.9) (1.4.0)
# Requirement already satisfied: aiohttp>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from langextract==1.0.9) (3.13.2)
# Requirement already satisfied: async_timeout>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from langextract==1.0.9) (5.0.1)
# Requirement already satisfied: exceptiongroup>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langextract==1.0.9) (1.3.1)
# Requirement already satisfied: ml-collections>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from langextract==1.0.9) (1.1.0)
# Requirement already satisfied: more-itertools>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from langextract==1.0.9) (10.8.0)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.12/dist-packages (from langextract==1.0.9) (6.0.3)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.12/dist-packages (from langextract==1.0.9) (4.67.1)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (0.4.43)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (2.0.44)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain_community==0.3.29) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community==0.3.29) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community==0.3.29) (0.4.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain_core==0.3.75) (1.33)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from langchain_core==0.3.75) (25.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai==2.1.10) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.18 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai==2.1.10) (0.6.18)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4==4.13.5) (2.8)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==1.0.20) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (3.11.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==1.0.20) (4.25.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (24.1.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (0.121.3)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (1.0.0)
# Requirement already satisfied: gradio-client==1.12.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (1.12.1)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (3.0.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (11.3.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (0.14.5)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1) (0.13.3)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1) (6.6.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1) (7.16.6)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1) (6.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1) (7.7.1)
# Requirement already satisfied: jupyterlab in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1) (4.5.0)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.7.1) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.7.1) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.7.1) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.2) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.6) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.6) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.6) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.6) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly==6.3.0) (2.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.1) (8.3.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.1) (2024.11.6)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn==0.5.9.post2) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn==0.5.9.post2) (0.5.13)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.12.1->gradio==5.44.1) (2025.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.0->langextract==1.0.9) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.0->langextract==1.0.9) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.0->langextract==1.0.9) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.0->langextract==1.0.9) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.0->langextract==1.0.9) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.0->langextract==1.0.9) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.0->langextract==1.0.9) (1.22.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai==1.33.0) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai==1.33.0) (1.3.1)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb==1.0.20) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.6.7->langchain_community==0.3.29) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.6.7->langchain_community==0.3.29) (0.9.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio==5.44.1) (0.0.4)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.10) (2.28.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.10) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.10) (5.29.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai==1.33.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai==1.33.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai==1.33.0) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai==1.33.0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai==1.33.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai==1.33.0) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.33.5->gradio==5.44.1) (3.20.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.33.5->gradio==5.44.1) (1.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain_core==0.3.75) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb==1.0.20) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb==1.0.20) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb==1.0.20) (0.29.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==1.0.20) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==1.0.20) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==1.0.20) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==1.0.20) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==1.0.20) (0.10)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain==0.3.27) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain==0.3.27) (0.25.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.2->umap-learn==0.5.9.post2) (0.43.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb==1.0.20) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb==1.0.20) (25.9.23)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb==1.0.20) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.2.0->chromadb==1.0.20) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.0.20) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.0.20) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.0.20) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.2.0->chromadb==1.0.20) (0.59b0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog<6.0.0,>=2.4.0->chromadb==1.0.20) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog<6.0.0,>=2.4.0->chromadb==1.0.20) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai==1.33.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai==1.33.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai==1.33.0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai==1.33.0) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb==1.0.20) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb==1.0.20) (2.19.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.27) (3.2.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb==1.0.20) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==1.0.20) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==1.0.20) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==1.0.20) (1.1.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter==1.1.1) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter==1.1.1) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter==1.1.1) (3.0.16)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter==1.1.1) (5.9.1)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter==1.1.1) (3.0.52)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1) (2.0.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1) (2.14.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1) (75.2.0)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1) (1.5.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1) (25.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1) (0.23.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1) (1.3.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1) (1.4.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.10) (1.71.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==1.0.20) (3.23.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter==1.1.1) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter==1.1.1) (4.5.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (0.5.3)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->jupyter==1.1.1) (25.1.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb==1.0.20) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert->jupyter==1.1.1) (2.21.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.1.1) (0.2.14)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai==1.33.0) (0.6.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->notebook->jupyter==1.1.1) (0.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain_community==0.3.29) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==1.0.20) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb==1.0.20) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb==1.0.20) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.1.1) (0.8.5)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (0.1.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.1.1) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.1.1) (2.23)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (20.11.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (1.4.0)

# %%
# test code for environment setup
# import library
import dotenv
from google import genai
import langextract
import langchain
from langchain_community import utils
from langchain_core import prompts
from langchain_google_genai import chat_models
from bs4 import BeautifulSoup
import chromadb
import gradio
import jupyter
import sklearn
import pandas
import numpy
import matplotlib
import plotly
import seaborn
import nltk
import umap
import pymupdf

# %matplotlib inline

# %% [markdown]
# ##### **OPTIONAL: If you want to save your outputs you can send them to your own drive by mounting the drive in the following way (uncomment the lines):**

# %%
# Remember to change the directory of your outputs to your folder in the new mounted google drive inside colab
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Data Mining Lab 2 - Phase 2](#toc1_)
#   - [Before Starting](#toc1_1_)
#   - [Introduction](#toc1_2_)
#   - [**1. Data Preparation**](#toc1_3_)
#   - [**1.1 Load data**](#toc1_4_)
#     - [**1.2 Save data**](#toc1_4_1_)
#   - [**2. Large Language Models (LLMs)**](#toc1_5_)
#     - [Open-Source vs. Proprietary LLMs](#toc1_5_1_)
#     - [Why Use Code (API) for Data Mining?](#toc1_5_2_)
#     - [The Gemini API](#toc1_5_3_)
#     - [Interacting with the Gemini API](#toc1_5_4_)
#     - [**2.1 Text Prompting**](#toc1_5_5_)
#         - [**>>> Exercise 1 (Take home):**](#toc1_5_5_1_1_)
#     - [**2.2 Structured Output**](#toc1_5_6_)
#         - [**>>> Exercise 2 (Take home):**](#toc1_5_6_1_1_)
#     - [**2.3 Information Extraction and Grounding:**](#toc1_5_7_)
#       - [**`langextract`: A Library for Grounded Extraction**](#toc1_5_7_1_)
#         - [**2.3.1 Using PDF Documents:**](#toc1_5_7_1_1_)
#         - [**>>> Bonus Exercise 3 (Take home):**](#toc1_5_7_1_2_)
#     - [**2.4 Generating LLM Embeddings:**](#toc1_5_8_)
#         - [**>>> Exercise 4 (Take home):**](#toc1_5_8_1_1_)
#     - [**2.5 Retrieval-Augmented Generation (RAG)**](#toc1_5_9_)
#         - [**Actual answer in the URL:**](#toc1_5_9_1_1_)
#         - [**Content in the URL that might get into the generated answer because of similar semantic meaning:**](#toc1_5_9_1_2_)
#         - [**>>> Bonus Exercise 5 (Take home):**](#toc1_5_9_1_3_)
#     - [**2.6 Few-Shot Prompting Classification:**](#toc1_5_10_)
#         - [**>>> Exercise 6 (Take home):**](#toc1_5_10_1_1_)
#         - [**>>> Exercise 7 (Take home):**](#toc1_5_10_1_2_)
#     - [**2.7 Extra LLM Related Materials:**](#toc1_5_11_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # Data Mining Lab 2 - Phase 2
# In this lab's phase 2 session we will focus on exploring some basic LLMs' applications with data.

# %% [markdown]
# ## Before Starting
#
# **Make sure you have installed all the required libraries and you have the environment ready to run this lab.**

# %% [markdown]
# ---
# ## Introduction

# %% [markdown]
# **Dataset:** [SemEval 2017 Task](https://competitions.codalab.org/competitions/16380)
#
# **Task:** Classify text data into 4 different emotions using word embeddings and other deep information retrieval approaches.
#
# ![pic0.png](https://drive.google.com/uc?export=view&id=1qurztXdx30Wl2vkCZg7KXXJYJXcE6YR_)

# %% [markdown]
# ---
# ## **1. Data Preparation**

# %% [markdown]
# ---
# ### **1.1 Load data**
#
# We start by loading the csv files into a single pandas dataframe for training and one for testing.

# %%
import pandas as pd

### training data
anger_train = pd.read_csv("./DM2025-Lab2-Exercise/data/semeval/train/anger-ratings-0to1.train.txt",
                         sep="\t", header=None,names=["id", "text", "emotion", "intensity"])
sadness_train = pd.read_csv("./DM2025-Lab2-Exercise/data/semeval/train/sadness-ratings-0to1.train.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
fear_train = pd.read_csv("./DM2025-Lab2-Exercise/data/semeval/train/fear-ratings-0to1.train.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
joy_train = pd.read_csv("./DM2025-Lab2-Exercise/data/semeval/train/joy-ratings-0to1.train.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])

# %%
# combine 4 sub-dataset
train_df = pd.concat([anger_train, fear_train, joy_train, sadness_train], ignore_index=True)

# %%
### testing data
anger_test = pd.read_csv("./DM2025-Lab2-Exercise/data/semeval/dev/anger-ratings-0to1.dev.gold.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
sadness_test = pd.read_csv("./DM2025-Lab2-Exercise/data/semeval/dev/sadness-ratings-0to1.dev.gold.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
fear_test = pd.read_csv("./DM2025-Lab2-Exercise/data/semeval/dev/fear-ratings-0to1.dev.gold.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
joy_test = pd.read_csv("./DM2025-Lab2-Exercise/data/semeval/dev/joy-ratings-0to1.dev.gold.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])

# combine 4 sub-dataset
test_df = pd.concat([anger_test, fear_test, joy_test, sadness_test], ignore_index=True)
train_df.head()
# Out:
#       id                                               text emotion  intensity
# 0  10000  How the fu*k! Who the heck! moved my fridge!.....   anger      0.938
# 1  10001  So my Indian Uber driver just called someone t...   anger      0.896
# 2  10002  @DPD_UK I asked for my parcel to be delivered ...   anger      0.896
# 3  10003  so ef whichever butt wipe pulled the fire alar...   anger      0.896
# 4  10004  Don't join @BTCare they put the phone down on ...   anger      0.896

# %%
# shuffle dataset
train_df = train_df.sample(frac=1)
test_df = test_df.sample(frac=1)

# %%
print("Shape of Training df: ", train_df.shape)
print("Shape of Testing df: ", test_df.shape)
# Out:
# Shape of Training df:  (3613, 4)
# Shape of Testing df:  (347, 4)

# %% [markdown]
# ---
# ### **1.2 Save data**

# %%
# save to pickle file
train_df.to_pickle("./DM2025-Lab2-Exercise/data/train_df.pkl")
test_df.to_pickle("./DM2025-Lab2-Exercise/data/test_df.pkl")

# %%
import pandas as pd

# load a pickle file
train_df = pd.read_pickle("./DM2025-Lab2-Exercise/data/train_df.pkl")
test_df = pd.read_pickle("./DM2025-Lab2-Exercise/data/test_df.pkl")

# %% [markdown]
# For more information: https://reurl.cc/0Dzqx

# %% [markdown]
# ---
# ## **2. Large Language Models (LLMs)**
#
# Before we start we strongly suggest that you watch the following video explanations so you can understand the concepts that we are gonna discuss about LLMs:
#
# 1. [How Large Language Models Work](https://www.youtube.com/watch?v=5sLYAQS9sWQ)
# 2. [Large Language Models explained briefly](https://www.youtube.com/watch?v=LPZh9BOjkQs)
# 3. [What is Prompt Tuning?](https://www.youtube.com/watch?v=yu27PWzJI_Y)
# 4. [Why Large Language Models Hallucinate](https://www.youtube.com/watch?v=cfqtFvWOfg0)
# 5. [What are LLM Embeddings?](https://www.youtube.com/watch?v=UShw_1NbpCw&t=182s)
# 6. [What is Retrieval-Augmented Generation (RAG)?](https://www.youtube.com/watch?v=T-D1OfcDW1M)
# 7. [RAG vs Fine-Tuning vs Prompt Engineering: Optimizing AI Models](https://www.youtube.com/watch?v=zYGDpG-pTho)
# 8. [Discover Few-Shot Prompting | Google AI Essentials](https://www.youtube.com/watch?v=9qdgEBVkWR4)
# 9. [What is Zero-Shot Learning?](https://www.youtube.com/watch?v=pVpr4GYLzAo)
# 10. [Zero-shot, One-shot and Few-shot Prompting Explained | Prompt Engineering 101](https://www.youtube.com/watch?v=sW5xoicq5TY)
#
# `These videos can help you get a better grasp on the core concepts of LLMs if you were not familiar before.`
#
# **So now let's start with the main content of Lab 2 Phase 2.**
#
# Large Language Models (LLMs) are AI systems trained on vast amounts of text to understand and generate human language for tasks like summarization and translation.
#
# ### Open-Source vs. Proprietary LLMs
# *   **Open-Source Models** (e.g., Llama, Gemma) are customizable and cost-effective but require technical skill to manage and may be less powerful.
# *   **Proprietary Models** (e.g., Gemini, ChatGPT) offer top performance and ease of use but are more costly and less flexible.
#
# For students interested in running models locally, the optional notebook `DM2025-Lab2-Optional-Ollama.ipynb` explores using Ollama ([Ollama GitHub Link](https://github.com/ollama/ollama)). It needs a capable GPU to run models (**at least 4GB VRAM**).
#
# You can explore the variety of models available through Ollama here:
#
# ![pic10.png](https://drive.google.com/uc?export=view&id=1ZvD7_yeSCETl98vXI5zo_TikF6Wpu0-r)
#
# ### Why Use Code (API) for Data Mining?
#
# For data analysis, accessing LLMs programmatically is superior to using web chatbots because it allows for:
# *   **Automation:** Easily process entire datasets with loops.
# *   **Structured Output:** Receive data in usable formats like **JSON**, ready for analysis in tools like pandas.
# *   **Reproducibility:** Ensure consistent results by setting fixed parameters.
# *   **Privacy:** Maintain data security, especially when running models locally.
#
# For the main exercises in this lab, we will use **the Gemini API**. This approach offers several advantages over running local open-source models, such as access to state-of-the-art model performance without needing specialized hardware. While the API has usage limits (rate limits and token quotas), it provides a generous **free tier** that is more than sufficient for our exercises.
#
# ![pic13.png](https://drive.google.com/uc?export=view&id=1UGHgSyH2-m2ZdjJXJ39_8RCgZov2z94d)
#
# ![pic14.png](https://drive.google.com/uc?export=view&id=1D0Q5KpS5bNIH8er0kb8SWt1nZJhfufWa)
#
# ### The Gemini API
#
# We will primarily use the **Gemini 2.5 Flash-Lite** (`gemini-2.5-flash-lite`) model. As shown in the rate limit table, this model is optimized for high-frequency tasks and offers a high request-per-day limit of 1,000, making it ideal for completing the lab exercises without interruption.
#
# Students are encouraged to explore other models available through the API but should remain mindful of their respective usage limits. For instance:
# *   **Gemini 2.5 Pro** is a more powerful model but has a lower daily request limit of 100.
# *   The **Gemma 3** model available via the API offers an impressive 14,400 requests per day, providing another excellent alternative for experimentation.
#
# Please be aware of your usage limits as you work through the exercises to ensure you do not get rate-limited.
#
# [Gemini Documentation](https://ai.google.dev/gemini-api/docs)
#
# [Gemini Rate Limits](https://ai.google.dev/gemini-api/docs/rate-limits)
#
# [Description of Gemini Models](https://ai.google.dev/gemini-api/docs/models)

# %% [markdown]
# ---
#
# ### Interacting with the Gemini API
#
# The code cell below contains the primary function, `prompt_gemini`, that we will use throughout this lab to communicate with the Gemini API. It's designed to be a flexible wrapper that handles the details of sending a request and receiving a response.
#
# Before you run the exercises, here are the key things you need to understand in this setup:
#
# *   **API Key Configuration**: The script loads your API key from a `.env` file located in the `./config/` directory. **You must create this file and add your API key** like this: `GOOGLE_API_KEY='YOUR_API_KEY_HERE'`. This is a security best practice to keep your credentials out of the code.
#
# *   **Global Settings**: At the top of the script, you can find and modify several important defaults:
#     *   `MODEL_NAME`: We've set this to `"gemini-2.5-flash-lite"`, but you can easily switch to other models like `"gemini-2.5-pro"` to experiment.
#     *   `SYSTEM_INSTRUCTION`: This sets the model's default behavior or persona (e.g., "You are a helpful assistant"). You can customize this for different tasks.
#     *   `SAFETY_SETTINGS`: For our academic exercises, these are turned off to prevent interference. In real-world applications, you would configure these carefully.
#
# *   **The `prompt_gemini` function**: This is the main tool you will use. Here are its most important parameters:
#     *   `input_prompt`: The list of contents (text, images, etc.) you want to send to the model.
#     *   `temperature`: Controls the randomness of the output. `0.0` makes the output deterministic and less creative, while a higher value (e.g., `0.7`) makes it more varied.
#     *   `schema`: A powerful feature that allows you to specify a JSON format for the model's output. This is extremely useful for structured data extraction.
#     *   `with_tokens_info`: If set to `True`, the function will also return the number of input and output tokens used, which is helpful for monitoring your usage against the free tier limits.
#
# In the following exercises, you will call this function with different prompts and configurations to solve various tasks.
#
# If needed, you can also check some tutorials on how a python function works: [Python Functions Tutorial](https://realpython.com/defining-your-own-python-function/)

# %%
import os
from google.colab import userdata
from google import genai
from google.genai import types


# System instruction that can dictate how the model behaves in the output, can be customized as needed
SYSTEM_INSTRUCTION = (
        "You are a helpful assistant"
    )

# Max amount of tokens that the model can output, the Gemini 2.5 Models have this maximum amount
# For other models need to check their documentation
MAX_OUTPUT_TOKENS = 65535
MODEL_NAME = "gemini-2.5-flash-lite" # Other models: "gemini-2.5-pro", "gemini-2.5-flash"; Check different max output tokens: "gemini-2.0-flash" , "gemini-2.0-flash-lite"

# We disable the safety settings, as no moderation is needed in our tasks
SAFETY_SETTINGS = [
    types.SafetySetting(
        category="HARM_CATEGORY_HATE_SPEECH", threshold="OFF"),
    types.SafetySetting(
        category="HARM_CATEGORY_DANGEROUS_CONTENT", threshold="OFF"),
    types.SafetySetting(
        category="HARM_CATEGORY_SEXUALLY_EXPLICIT", threshold="OFF"),
    types.SafetySetting(
        category="HARM_CATEGORY_HARASSMENT", threshold="OFF")
]

# We input the API Key to be able to use the Gemini models
api_key = userdata.get('GOOGLE_API_KEY')
os.environ["GOOGLE_API_KEY"] = api_key
client = genai.Client(api_key=api_key)

# We also set LangExtract to use the API key as well:
if 'GEMINI_API_KEY' not in os.environ:
    os.environ['GEMINI_API_KEY'] = api_key

def prompt_gemini(
        input_prompt: list,
        schema = None,
        temperature: float = 0.0,
        system_instruction: str = SYSTEM_INSTRUCTION,
        max_output_tokens: int = MAX_OUTPUT_TOKENS,
        client: genai.Client = client,
        model_name: str = MODEL_NAME,
        new_config: types.GenerateContentConfig = None,
        with_tools: bool = False,
        with_parts: bool = False,
        with_tokens_info: bool = False
    ):
        try:
            # If we need a JSON schema we set up the following
            if schema:
                generate_content_config = types.GenerateContentConfig(
                    temperature=temperature,
                    system_instruction=system_instruction,
                    max_output_tokens=max_output_tokens,
                    response_modalities=["TEXT"],
                    response_mime_type="application/json",
                    response_schema=schema,
                    safety_settings=SAFETY_SETTINGS
                )
            # If there is no need we leave it unstructured
            else:
                generate_content_config = types.GenerateContentConfig(
                    temperature=temperature,
                    system_instruction=system_instruction,
                    max_output_tokens=max_output_tokens,
                    response_modalities=["TEXT"],
                    safety_settings=SAFETY_SETTINGS
                )

            # We add a different custom configuration if we need it
            if new_config:
                generate_content_config = new_config

            # For some tasks we need a more specific way to add the contents when prompting the model
            # So we need custom parts for it sometimes from the "types" objects
            if with_parts:
                response = client.models.generate_content(
                    model=model_name,
                    contents=types.Content(parts=input_prompt),
                    config=generate_content_config,
                )
            # In the simplest form the contents can be expressed as a list [] of simple objects like str and Pillow images
            else:
                response = client.models.generate_content(
                    model=model_name,
                    contents=input_prompt,
                    config=generate_content_config,
                )

            if with_tools:
                # print(response)
                # Include raw response when function calling
                completion = response
                if with_tokens_info:
                    log = {
                        "model": model_name,
                        "input_tokens": response.usage_metadata.prompt_token_count,
                        "output_tokens": response.usage_metadata.candidates_token_count,
                    }
                    return completion, log
                return completion
            else:
                completion = response.text
                if with_tokens_info:
                    log = {
                        "model": model_name,
                        "input_tokens": response.usage_metadata.prompt_token_count,
                        "output_tokens": response.usage_metadata.candidates_token_count,
                    }
                    # Return the text response and logs (if selected)
                    return completion, log
                return completion
        except Exception as e:
             print(f"Error occurred when generating response, error: {e}")
             return None

# %% [markdown]
# ---
# ### **2.1 Text Prompting**
#
# In the same way as with ChatGPT we can use the Gemini models to ask about anything. Here we are going to ask a question requesting the response to be in markdown format, this is to make it have a better display afterwards.
#
# For more information visit:
# [Gemini's Text Generation Documentation](https://ai.google.dev/gemini-api/docs/text-generation)

# %%
input_prompt = ["What is Data Mining?"]
text_response, logs = prompt_gemini(input_prompt = input_prompt, with_tokens_info = True)
print(text_response)
# Out:
# Data mining is the process of **discovering patterns, insights, and knowledge from large datasets**. It's essentially about extracting valuable information that isn't immediately obvious from raw data. Think of it as sifting through a mountain of information to find hidden gems.
#
# Here's a breakdown of what that means:
#
# **Key Concepts:**
#
# *   **Large Datasets:** Data mining is typically applied to datasets that are too large and complex for manual analysis. This can include customer transaction records, website logs, sensor data, social media feeds, scientific experiment results, and much more.
# *   **Patterns and Insights:** The goal is to identify recurring trends, correlations, anomalies, and relationships within the data. These patterns can reveal underlying structures, predict future behavior, or explain observed phenomena.
# *   **Knowledge Discovery:** The ultimate aim is to transform raw data into actionable knowledge that can be used for decision-making, problem-solving, and strategic planning.
#
# **How it Works (The Process):**
#
# Data mining is usually an iterative process that involves several stages:
#
# 1.  **Business Understanding:** Defining the problem or objective you want to achieve with data mining. What questions are you trying to answer? What business goals are you trying to meet?
# 2.  **Data Understanding:** Exploring and getting familiar with the data. This involves collecting, cleaning, and understanding the data's structure, quality, and meaning.
# 3.  **Data Preparation (Preprocessing):** This is often the most time-consuming stage. It involves:
#     *   **Cleaning:** Handling missing values, noisy data, and inconsistencies.
#     *   **Integration:** Combining data from multiple sources.
#     *   **Transformation:** Normalizing or aggregating data to make it suitable for mining.
#     *   **Reduction:** Reducing the size of the dataset while preserving important information.
# 4.  **Modeling:** Selecting and applying appropriate data mining techniques (algorithms) to discover patterns. This is where the "mining" happens.
# 5.  **Evaluation:** Assessing the quality and usefulness of the discovered patterns. Do they make sense? Are they statistically significant? Do they meet the business objectives?
# 6.  **Deployment:** Putting the discovered knowledge into practice. This could involve integrating it into business processes, creating reports, or building predictive models.
#
# **Common Data Mining Techniques:**
#
# Data mining employs a variety of techniques, often drawing from statistics, machine learning, and database systems. Some of the most common include:
#
# *   **Classification:** Categorizing data into predefined classes (e.g., predicting whether a customer will churn or not).
# *   **Clustering:** Grouping similar data points together without predefined classes (e.g., segmenting customers into different groups based on their purchasing behavior).
# *   **Association Rule Mining:** Discovering relationships between items in a dataset (e.g., "customers who buy bread also tend to buy milk"). This is often used in market basket analysis.
# *   **Regression:** Predicting a continuous numerical value (e.g., predicting the price of a house based on its features).
# *   **Anomaly Detection (Outlier Detection):** Identifying data points that deviate significantly from the norm (e.g., detecting fraudulent transactions).
# *   **Sequential Pattern Mining:** Discovering patterns that occur in a sequence over time (e.g., identifying common user navigation paths on a website).
#
# **Why is Data Mining Important?**
#
# Data mining is crucial for businesses and organizations because it enables them to:
#
# *   **Make Better Decisions:** By understanding customer behavior, market trends, and operational efficiencies, organizations can make more informed and strategic decisions.
# *   **Improve Customer Relationships:** Identifying customer preferences and predicting their needs allows for personalized marketing, better customer service, and increased loyalty.
# *   **Detect Fraud and Risk:** Anomaly detection can help identify fraudulent activities, security breaches, and potential risks.
# *   **Optimize Operations:** Understanding patterns in operational data can lead to improved efficiency, reduced costs, and better resource allocation.
# *   **Drive Innovation:** Discovering new insights can spark new product development, service offerings, and business models.
# *   **Gain a Competitive Advantage:** Organizations that effectively leverage data mining can outperform their competitors by understanding their market and customers better.
#
# In essence, data mining is a powerful tool for transforming raw data into valuable intelligence, driving progress and innovation across various fields.

# %% [markdown]
# We can also check the logs of the usage with our model that we defined in our previous function. We can observe the model we used, how many tokens where in the prompt in the input, and the output text response tokens of our model.

# %%
print(logs)
# Out:
# {'model': 'gemini-2.5-flash-lite', 'input_tokens': 12, 'output_tokens': 911}

# %% [markdown]
# **We can use the IPython library to make the response look better:**

# %%
from IPython.display import display, Markdown
display(Markdown(text_response))
# Out:
# Data mining is the process of **discovering patterns, insights, and knowledge from large datasets**. It's essentially about extracting valuable information that isn't immediately obvious from raw data. Think of it as sifting through a mountain of information to find hidden gems.
#
# Here's a breakdown of what that means:
#
# **Key Concepts:**
#
# *   **Large Datasets:** Data mining is typically applied to datasets that are too large and complex for manual analysis. This can include customer transaction records, website logs, sensor data, social media feeds, scientific experiment results, and much more.
# *   **Patterns and Insights:** The goal is to identify recurring trends, correlations, anomalies, and relationships within the data. These patterns can reveal underlying structures, predict future behavior, or explain observed phenomena.
# *   **Knowledge Discovery:** The ultimate aim is to transform raw data into actionable knowledge that can be used for decision-making, problem-solving, and strategic planning.
#
# **How it Works (The Process):**
#
# Data mining is usually an iterative process that involves several stages:
#
# 1.  **Business Understanding:** Defining the problem or objective you want to achieve with data mining. What questions are you trying to answer? What business goals are you trying to meet?
# 2.  **Data Understanding:** Exploring and getting familiar with the data. This involves collecting, cleaning, and understanding the data's structure, quality, and meaning.
# 3.  **Data Preparation (Preprocessing):** This is often the most time-consuming stage. It involves:
#     *   **Cleaning:** Handling missing values, noisy data, and inconsistencies.
#     *   **Integration:** Combining data from multiple sources.
#     *   **Transformation:** Normalizing or aggregating data to make it suitable for mining.
#     *   **Reduction:** Reducing the size of the dataset while preserving important information.
# 4.  **Modeling:** Selecting and applying appropriate data mining techniques (algorithms) to discover patterns. This is where the "mining" happens.
# 5.  **Evaluation:** Assessing the quality and usefulness of the discovered patterns. Do they make sense? Are they statistically significant? Do they meet the business objectives?
# 6.  **Deployment:** Putting the discovered knowledge into practice. This could involve integrating it into business processes, creating reports, or building predictive models.
#
# **Common Data Mining Techniques:**
#
# Data mining employs a variety of techniques, often drawing from statistics, machine learning, and database systems. Some of the most common include:
#
# *   **Classification:** Categorizing data into predefined classes (e.g., predicting whether a customer will churn or not).
# *   **Clustering:** Grouping similar data points together without predefined classes (e.g., segmenting customers into different groups based on their purchasing behavior).
# *   **Association Rule Mining:** Discovering relationships between items in a dataset (e.g., "customers who buy bread also tend to buy milk"). This is often used in market basket analysis.
# *   **Regression:** Predicting a continuous numerical value (e.g., predicting the price of a house based on its features).
# *   **Anomaly Detection (Outlier Detection):** Identifying data points that deviate significantly from the norm (e.g., detecting fraudulent transactions).
# *   **Sequential Pattern Mining:** Discovering patterns that occur in a sequence over time (e.g., identifying common user navigation paths on a website).
#
# **Why is Data Mining Important?**
#
# Data mining is crucial for businesses and organizations because it enables them to:
#
# *   **Make Better Decisions:** By understanding customer behavior, market trends, and operational efficiencies, organizations can make more informed and strategic decisions.
# *   **Improve Customer Relationships:** Identifying customer preferences and predicting their needs allows for personalized marketing, better customer service, and increased loyalty.
# *   **Detect Fraud and Risk:** Anomaly detection can help identify fraudulent activities, security breaches, and potential risks.
# *   **Optimize Operations:** Understanding patterns in operational data can lead to improved efficiency, reduced costs, and better resource allocation.
# *   **Drive Innovation:** Discovering new insights can spark new product development, service offerings, and business models.
# *   **Gain a Competitive Advantage:** Organizations that effectively leverage data mining can outperform their competitors by understanding their market and customers better.
#
# In essence, data mining is a powerful tool for transforming raw data into valuable intelligence, driving progress and innovation across various fields.

# %% [markdown]
# ---
# ##### **>>> Exercise 1 (Take home):**
#
# `With your own prompt`, run the previous example in the following way:
#
# 1. Run it with the same model as the example (gemini-2.5-flash-lite).
# 2. Run it with a different gemini model from the available options for the API.
# 3. Discuss the differences on the results with different models.
# 4. Discuss what would happen if you change the system prompt.

# %% [markdown]
# ###### Model1: gemini-2.5-flash-lite (same system prompt)

# %%
input_prompt_Flash = ["What is FinTech?"]
text_response_Flash, logs_Flash = prompt_gemini(input_prompt = input_prompt_Flash, model_name = "gemini-2.5-flash-lite", with_tokens_info = True)
display(Markdown(text_response_Flash))
# Out:
# FinTech is a portmanteau of **"financial technology."** In essence, it refers to the **use of technology to improve and automate the delivery and use of financial services.**
#
# Think of it as the intersection of finance and technology. FinTech companies and solutions aim to make financial services more accessible, efficient, and user-friendly for both consumers and businesses.
#
# Here's a breakdown of what that means and what it encompasses:
#
# **Key Characteristics of FinTech:**
#
# *   **Technology-Driven:** It leverages a wide range of technologies, including mobile apps, artificial intelligence (AI), machine learning (ML), blockchain, big data analytics, cloud computing, and more.
# *   **Innovation:** FinTech often disrupts traditional financial models and introduces new ways of doing things.
# *   **Customer-Centric:** Many FinTech solutions are designed with the end-user in mind, focusing on convenience, speed, and personalized experiences.
# *   **Efficiency and Automation:** Technology is used to streamline processes, reduce costs, and automate tasks that were previously manual or time-consuming.
# *   **Accessibility:** FinTech can make financial services available to a wider audience, including those who may have been underserved by traditional institutions.
#
# **Common Areas and Examples of FinTech:**
#
# *   **Digital Payments:**
#     *   **Mobile Wallets:** Apple Pay, Google Pay, Samsung Pay
#     *   **Peer-to-Peer (P2P) Payments:** Venmo, PayPal, Zelle
#     *   **Online Payment Gateways:** Stripe, Square
# *   **Lending and Borrowing:**
#     *   **Online Lenders:** Companies that offer loans through digital platforms, often with faster approval processes.
#     *   **Peer-to-Peer (P2P) Lending Platforms:** Connecting individual borrowers with individual lenders.
#     *   **Crowdfunding:** Platforms like Kickstarter and Indiegogo for raising capital.
# *   **Personal Finance Management:**
#     *   **Budgeting Apps:** Mint, YNAB (You Need A Budget)
#     *   **Investment Apps:** Robinhood, Acorns, Betterment (robo-advisors)
#     *   **Credit Score Trackers:** Credit Karma
# *   **Banking and Neobanks:**
#     *   **Digital-Only Banks (Neobanks):** Chime, Revolut, N26, Monzo – these banks operate entirely online with no physical branches.
#     *   **Online Banking Features:** Enhanced mobile banking apps, faster account opening.
# *   **Insurance (InsurTech):**
#     *   **Online Insurance Platforms:** Lemonade, Root
#     *   **Usage-Based Insurance:** Premiums based on how you use a product (e.g., driving habits).
# *   **Cryptocurrency and Blockchain:**
#     *   **Cryptocurrency Exchanges:** Coinbase, Binance
#     *   **Decentralized Finance (DeFi):** Financial applications built on blockchain technology, aiming to remove intermediaries.
# *   **Wealth Management and Investment:**
#     *   **Robo-Advisors:** Automated investment platforms that create and manage portfolios based on your goals.
#     *   **Online Brokerages:** Offering easy access to stock trading.
# *   **Regulatory Technology (RegTech):**
#     *   Technology solutions that help financial institutions comply with regulations more efficiently.
#
# **Why is FinTech Important?**
#
# *   **For Consumers:** It offers greater convenience, lower fees, faster transactions, and more personalized financial experiences.
# *   **For Businesses:** It can improve operational efficiency, reduce costs, expand market reach, and offer new revenue streams.
# *   **For the Financial Industry:** It drives innovation, competition, and can lead to greater financial inclusion.
#
# In summary, FinTech is a broad and rapidly evolving field that is transforming how we manage, spend, save, and invest our money.

# %%
print(logs_Flash)
# Out:
# {'model': 'gemini-2.5-flash-lite', 'input_tokens': 12, 'output_tokens': 815}

# %% [markdown]
# ###### Model2: gemini-2.5-pro (same system prompt)

# %%
input_prompt_Pro = ["What is FinTech?"]
text_response_Pro, logs_Pro = prompt_gemini(input_prompt = input_prompt_Pro, model_name = "gemini-2.5-pro", with_tokens_info = True) # Notice: it may run with error code 429 for too many utilizers
display(Markdown(text_response_Pro))
# Out:
# Of course! Here is a comprehensive explanation of FinTech.
#
# ### At its Core: A Simple Definition
#
# **FinTech**, short for **Financial Technology**, is any technology used to improve, automate, or disrupt traditional financial services.
#
# Think of it this way: FinTech is the engine behind why you can send money to a friend with an app, get a loan without ever stepping into a bank, or buy stocks from your phone for free.
#
# ---
#
# ### A Deeper Dive
#
# FinTech isn't just about startups trying to compete with big banks. It also includes established financial institutions and technology companies that are adopting new tech to improve their services. The ultimate goal is to make financial services more **accessible, efficient, and user-friendly** for both consumers and businesses.
#
# It challenges the old way of doing things—long lines, complex paperwork, high fees, and 9-to-5 business hours—by putting the power of banking, investing, and payments directly into the user's hands, usually through a smartphone.
#
# ---
#
# ### Key Areas and Everyday Examples
#
# You probably use FinTech every day without even realizing it. Here are the major categories with popular examples:
#
# #### 1. Digital Payments
# This is the most common form of FinTech. It involves moving money electronically without physical cash or checks.
# *   **Peer-to-Peer (P2P) Payments:** Apps that let you instantly send money to friends and family.
#     *   **Examples:** Venmo, PayPal, Zelle, Cash App
# *   **Mobile Wallets:** Storing your credit/debit card information on your phone for easy payments.
#     *   **Examples:** Apple Pay, Google Pay, Samsung Pay
#
# #### 2. Digital Lending & Crowdfunding
# Technology has transformed how individuals and businesses borrow money, often bypassing traditional banks.
# *   **Peer-to-Peer (P2P) Lending:** Online platforms that match borrowers directly with individuals or groups willing to lend money.
#     *   **Examples:** LendingClub, Prosper
# *   **"Buy Now, Pay Later" (BNPL):** Services that let you purchase an item and pay for it in installments.
#     *   **Examples:** Klarna, Afterpay, Affirm
# *   **Crowdfunding:** Platforms that allow a large number of people to invest small amounts of money in a business or project.
#     *   **Examples:** Kickstarter, GoFundMe
#
# #### 3. Investing & Trading (Robo-Advisors)
# FinTech has democratized investing, making it accessible to everyone, not just the wealthy.
# *   **Robo-Advisors:** Automated, algorithm-driven platforms that build and manage an investment portfolio for you based on your goals and risk tolerance.
#     *   **Examples:** Betterment, Wealthfront
# *   **Commission-Free Trading:** Apps that allow you to buy and sell stocks, ETFs, and other assets with zero commission fees.
#     *   **Examples:** Robinhood, Fidelity, Charles Schwab (their app versions)
#
# #### 4. Personal Finance & Budgeting
# Apps that help you track your spending, manage your budget, and improve your financial health.
# *   **Examples:** Mint, YNAB (You Need A Budget), Personal Capital
#
# #### 5. Digital Banking (Neobanks)
# These are banks that operate entirely online, without any physical branches. They often offer lower fees and a better user experience through their mobile apps.
# *   **Examples:** Chime, Revolut, N26
#
# #### 6. Insurance (InsurTech)
# This sub-field applies technology to the insurance industry to streamline claims, customize policies, and lower costs.
# *   **Examples:** Lemonade (uses AI to process claims in seconds), Root Insurance (bases car insurance rates on your driving behavior).
#
# #### 7. Cryptocurrency & Blockchain
# This is one of the most disruptive areas of FinTech. Blockchain is the secure and decentralized ledger technology that powers cryptocurrencies.
# *   **Examples:** Bitcoin, Ethereum, and crypto exchanges like Coinbase and Binance.
#
# ---
#
# ### Why is FinTech So Important?
#
# *   **Increased Convenience:** Access financial services 24/7 from anywhere.
# *   **Lower Costs:** Automation and reduced overhead (like no physical branches) often lead to lower fees for consumers.
# *   **Greater Accessibility (Financial Inclusion):** FinTech can provide essential financial services to people in underserved or remote areas who may not have access to a traditional bank.
# *   **Improved User Experience:** FinTech companies are laser-focused on creating simple, intuitive, and fast digital experiences.
# *   **Increased Competition:** The rise of FinTech has forced traditional banks to innovate and improve their own services to stay competitive.
#
# ### The Technologies Driving FinTech
#
# *   **Artificial Intelligence (AI) and Machine Learning:** Used for credit scoring, fraud detection, customer service chatbots, and personalized financial advice.
# *   **Blockchain:** Provides a secure and transparent way to record transactions, powering cryptocurrencies and more.
# *   **Cloud Computing:** Allows FinTech companies to store vast amounts of data and scale their services quickly and affordably.
# *   **Mobile Technology:** The smartphone is the primary platform for delivering FinTech services to the masses.
#
# ### In a Nutshell
#
# Think of what **Netflix did to Blockbuster** or what **Amazon did to traditional retail**. **FinTech is doing the same thing to traditional banking and finance.** It's using technology to offer a faster, cheaper, and more convenient alternative.

# %%
print(logs_Pro)
# Out:
# {'model': 'gemini-2.5-pro', 'input_tokens': 12, 'output_tokens': 1159}

# %%
# Basically, Model2 (gemini-2.5-pro (same system prompt)) performed better than Model1  (gemini-2.5-flash-lite (same system prompt)) for the content provided since Model2 generated more accurate answer for the definition of FinTech and more details for it (e.g., more examples and applications).

# %% [markdown]
# ###### Model3: gemini-2.5-flash-lite (FinTech system prompt)

# %%
input_prompt_Flash = ["What is FinTech?"]
text_response_Flash, logs_Flash = prompt_gemini(input_prompt = input_prompt_Flash, system_instruction = "You are FinTech expert", model_name = "gemini-2.5-flash-lite", with_tokens_info = True)
display(Markdown(text_response_Flash))
# Out:
# FinTech, short for **Financial Technology**, refers to the **use of technology to deliver financial services and products in new and innovative ways.** It's essentially the intersection of finance and technology, aiming to make financial services more efficient, accessible, and user-friendly.
#
# Think of it as a broad umbrella term that encompasses a wide range of companies, technologies, and applications that are transforming how we manage, spend, save, borrow, and invest our money.
#
# Here's a breakdown of what FinTech entails:
#
# **Key Characteristics of FinTech:**
#
# *   **Technology-Driven:** It leverages a variety of technologies, including:
#     *   **Mobile Applications:** For banking, payments, investing, and more.
#     *   **Artificial Intelligence (AI) and Machine Learning (ML):** For personalized recommendations, fraud detection, risk assessment, and automated advisory services.
#     *   **Big Data Analytics:** To understand customer behavior, identify trends, and improve services.
#     *   **Blockchain and Distributed Ledger Technology (DLT):** For secure and transparent transactions, cryptocurrencies, and smart contracts.
#     *   **Cloud Computing:** To enable scalability, accessibility, and cost-effectiveness.
#     *   **APIs (Application Programming Interfaces):** To connect different financial services and create seamless user experiences.
# *   **Customer-Centric:** FinTech often focuses on improving the customer experience by offering:
#     *   **Convenience:** Access to services anytime, anywhere.
#     *   **Speed:** Faster transactions and approvals.
#     *   **Personalization:** Tailored products and advice.
#     *   **Lower Costs:** Often more competitive pricing than traditional institutions.
# *   **Disruptive:** FinTech companies often challenge traditional financial institutions (banks, insurance companies, investment firms) by offering more agile, innovative, and often cheaper alternatives.
# *   **Data-Intensive:** FinTech relies heavily on data to drive its services and improve its offerings.
#
# **Common Areas and Examples of FinTech:**
#
# *   **Digital Payments:**
#     *   **Mobile Wallets:** Apple Pay, Google Pay, Samsung Pay.
#     *   **Peer-to-Peer (P2P) Payment Apps:** Venmo, PayPal, Zelle.
#     *   **Online Payment Gateways:** Stripe, Square.
# *   **Lending and Borrowing:**
#     *   **Online Lenders/P2P Lending Platforms:** LendingClub, Prosper (connecting borrowers with investors).
#     *   **Digital Mortgages:** Rocket Mortgage.
#     *   **Buy Now, Pay Later (BNPL) Services:** Klarna, Afterpay, Affirm.
# *   **Personal Finance Management (PFM):**
#     *   **Budgeting Apps:** Mint, YNAB (You Need A Budget).
#     *   **Investment Tracking Apps:** Personal Capital.
# *   **Investing and Wealth Management:**
#     *   **Robo-Advisors:** Betterment, Wealthfront (automated investment management).
#     *   **Online Brokerages:** Robinhood, Charles Schwab (for stock trading).
#     *   **Cryptocurrency Exchanges:** Coinbase, Binance.
# *   **InsurTech (Insurance Technology):**
#     *   **Online Insurance Platforms:** Lemonade, Oscar Health.
#     *   **Usage-Based Insurance:** Geico's Drive Safe & Save.
# *   **RegTech (Regulatory Technology):**
#     *   Technologies that help financial institutions comply with regulations more efficiently.
# *   **Crowdfunding:**
#     *   Platforms like Kickstarter and Indiegogo for raising capital.
#
# **Why is FinTech Important?**
#
# *   **Increased Financial Inclusion:** It can provide access to financial services for underserved populations who may not have access to traditional banking.
# *   **Enhanced Efficiency:** Automating processes and streamlining operations leads to faster and cheaper services.
# *   **Improved Customer Experience:** Offers more convenient, personalized, and user-friendly ways to manage finances.
# *   **Innovation and Competition:** Drives innovation within the financial industry, leading to better products and services for everyone.
# *   **Economic Growth:** Creates new businesses, jobs, and investment opportunities.
#
# In essence, FinTech is reshaping the financial landscape, making it more dynamic, accessible, and technologically advanced. It's a rapidly evolving field, and its impact on our daily lives is only set to grow.

# %% [markdown]
# ###### Model4: gemini-2.5-pro (FinTech system prompt)

# %%
input_prompt_Pro = ["What is FinTech?"]
text_response_Pro, logs_Pro = prompt_gemini(input_prompt = input_prompt_Pro, system_instruction = "You are FinTech expert", model_name = "gemini-2.5-pro", with_tokens_info = True) # Notice: it may run with error code 429 for too many utilizers
display(Markdown(text_response_Pro))
# Out:
# Of course. As a FinTech expert, I'd be happy to break this down for you.
#
# Let's start with the simple definition and then explore the details.
#
# ### The Simple Definition
#
# **FinTech**, short for "Financial Technology," is any technology used to improve, automate, or disrupt traditional financial services.
#
# Think of it this way: FinTech is what happens when you apply the speed, convenience, and user-friendliness of the internet and smartphones to the world of banking, investing, and payments.
#
# ### The Deeper Dive: What It Really Means
#
# For decades, finance was dominated by large, slow-moving institutions: banks, insurance companies, and investment firms. You had to physically go to a branch, fill out paperwork, and deal with processes that hadn't changed much in 50 years.
#
# FinTech companies looked at this and asked, "Why can't managing money be as easy as ordering a pizza or hailing a ride on your phone?"
#
# The core goal of FinTech is to make financial services:
#
# *   **More Accessible:** Allowing anyone with a smartphone to access services that were once exclusive or difficult to obtain (like investing or getting a loan).
# *   **More Efficient:** Automating manual processes to make things faster and reduce errors.
# *   **Less Expensive:** Cutting out middlemen and physical infrastructure (like bank branches) to lower fees for consumers.
# *   **More User-Friendly:** Designing intuitive apps and websites that focus on a great customer experience.
#
# ---
#
# ### Key Areas of FinTech (with Examples)
#
# FinTech isn't just one thing; it's a vast ecosystem covering many different areas. Here are the most important ones:
#
# #### 1. Digital Payments
# This is the most common form of FinTech you use every day. It's about moving money without using cash or physical checks.
# *   **Examples:** **PayPal**, **Venmo**, **Stripe** (powers payments for millions of online businesses), **Apple Pay**, **Block (formerly Square)**.
#
# #### 2. Digital Lending
# Online platforms that connect borrowers directly with lenders (or lend their own capital), using data and algorithms to make credit decisions in minutes, not weeks.
# *   **Examples:** **SoFi** (student loans, personal loans), **Klarna** and **Affirm** (Buy Now, Pay Later services), **Rocket Mortgage**.
#
# #### 3. Personal Finance & Wealth Management ("WealthTech")
# Making investing and financial planning accessible to everyone, not just the wealthy. This includes robo-advisors that use algorithms to manage your investment portfolio for a very low fee.
# *   **Examples:** **Robinhood** (commission-free stock trading), **Betterment** and **Wealthfront** (robo-advisors), **Mint** (budgeting app), **Acorns** (micro-investing).
#
# #### 4. InsurTech
# Using technology to modernize the insurance industry. This includes everything from using AI to process claims faster to using data from your smartphone to offer you a better car insurance rate.
# *   **Examples:** **Lemonade** (uses AI and chatbots for home and renters insurance), **Root Insurance** (bases car insurance rates on your actual driving behavior tracked via an app).
#
# #### 5. Blockchain & Cryptocurrency
# Leveraging decentralized, secure digital ledgers (blockchain) to create new financial assets and systems. This is the technology that powers Bitcoin, Ethereum, and thousands of other digital currencies.
# *   **Examples:** **Coinbase** (a platform to buy and sell crypto), **MetaMask** (a crypto wallet), **Circle** (issuer of the USDC stablecoin).
#
# #### 6. RegTech (Regulatory Technology)
# Helping financial companies comply with complex government regulations more efficiently and cheaply, often using AI to monitor for fraud and money laundering.
# *   **Examples:** **ComplyAdvantage**, **Chainalysis** (monitors blockchain transactions for illicit activity).
#
# #### 7. Embedded Finance & BaaS (Banking-as-a-Service)
# This is a huge, emerging trend. It's the idea of putting a financial product inside a non-financial company's app or service. BaaS providers offer the back-end infrastructure that allows this to happen.
# *   **The Classic Example:** When you take an **Uber**, you pay for the ride seamlessly within the app. You don't pull out a credit card machine. That's embedded payments.
# *   **Other Examples:** **Shopify** offering loans and bank accounts directly to its merchants; an airline offering travel insurance at checkout.
#
# ---
#
# ### Why is FinTech Such a Big Deal?
#
# FinTech is fundamentally changing our relationship with money.
#
# 1.  **Financial Inclusion:** It's bringing banking and investment services to people in underserved communities who may not have access to a traditional bank branch.
# 2.  **Customer Empowerment:** It gives consumers more choice, transparency, and control over their finances than ever before.
# 3.  **Disruption:** It's forcing traditional banks and financial institutions to innovate and improve their own services to compete, which is a win for everyone.
# 4.  **Data-Driven Decisions:** FinTech uses vast amounts of data to create more personalized products, assess risk more accurately, and offer better advice.
#
# In short, **FinTech is to finance what e-commerce was to retail.** It took an old, physical industry and rebuilt it for the digital age, putting the customer at the center of the experience.

# %%
# Both Mode3 (gemini-2.5-flash-lite (FinTech system prompt)) and Model4 (gemini-2.5-pro (FinTech system prompt)) performed better over Model1 (gemini-2.5-pro (same system prompt)) performed better over Model1 (gemini-2.5-flash-lite (same system prompt)) and Model2 (gemini-2.5-pro (same system prompt)) with better description the defintion and subfield of FinTech. (However, those who are utlized FinTech system prompt sometimes show what they are designed; that is, reveal to users that they are FinTech expert)

# %% [markdown]
# ---
# ### **2.2 Structured Output**
#
# By default, an LLM responds with unstructured, free-form text. For data mining, this is often impractical, as we need data in a predictable format to load into tools like a pandas DataFrame for analysis. **Structured output** is a powerful feature that forces the model to return its response in a specific, machine-readable format, such as JSON.
#
# The key to enabling this is to provide the model with a **response schema**. This schema acts as a strict template or blueprint that the model's output must conform to. Instead of generating a paragraph, the model will fill in the fields defined in your schema with the relevant information it extracts from the prompt.
#
# In the following code, we define this schema using Python classes. Think of each class as defining a JSON object:
# *   The **attributes** of the class (e.g., `topic_name`, `sub_title`) become the keys in the final JSON object.
# *   The **type hints** for those attributes (e.g., `str`, `list`) tell the model what kind of data is expected for each key's value.
#
# We can even nest these classes inside one another to create complex, hierarchical JSON structures. This allows us to precisely control the format of the output, transforming the LLM from a simple text generator into a reliable tool for automated and structured data extraction.
#
# [Gemini's Structured Output Documentation](https://ai.google.dev/gemini-api/docs/structured-output)
#
# For data validation of schemas Gemini API uses the Pydantic library, for more documentation on it you can check: [Pydantic](https://docs.pydantic.dev/latest/)
#
# [JSON Format Documentation](https://docs.python.org/3/library/json.html)

# %%
from pydantic import BaseModel

# We define our structure schema that Gemini should follow for the output response

# Subsections on the topics we query
class Subsection(BaseModel):
    sub_title: str
    sub_explanation: str

# The top-level structure for the entire topic analysis
class Topic(BaseModel):
    topic_name: str
    subsections: list[Subsection]

# %%
input_prompt = ["Explain what are machine learning, data centers, llms and how do they relate to each other."]
text_response = prompt_gemini(input_prompt = input_prompt, schema = list[Topic])
print(text_response)
# Out:
# [
#   {
#     "topic_name": "Machine Learning",
#     "subsections": [
#       {
#         "sub_title": "Definition",
#         "sub_explanation": "Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on building systems that can learn from and make decisions based on data. Instead of being explicitly programmed, ML algorithms use statistical techniques to enable systems to 'learn' from data, identify patterns, and make predictions or decisions without human intervention."
#       },
#       {
#         "sub_title": "Types of Machine Learning",
#         "sub_explanation": "Common types include supervised learning (learning from labeled data), unsupervised learning (finding patterns in unlabeled data), and reinforcement learning (learning through trial and error with rewards and penalties)."
#       },
#       {
#         "sub_title": "Applications",
#         "sub_explanation": "ML is used in a wide range of applications, such as image recognition, natural language processing, recommendation systems, fraud detection, and medical diagnosis."
#       }
#     ]
#   },
#   {
#     "topic_name": "Data Centers",
#     "subsections": [
#       {
#         "sub_title": "Definition",
#         "sub_explanation": "A data center is a dedicated physical facility that an organization uses to house its critical IT infrastructure, including servers, storage systems, networking equipment, and related components. These facilities are designed to provide a secure, reliable, and controlled environment for computing operations."
#       },
#       {
#         "sub_title": "Key Components",
#         "sub_explanation": "Essential components include servers, storage devices, network switches and routers, power supplies (including UPS and generators), cooling systems (HVAC), and physical security measures."
#       },
#       {
#         "sub_title": "Purpose",
#         "sub_explanation": "Data centers serve as the central hub for data storage, processing, and management, enabling businesses to run applications, host websites, and manage their digital operations."
#       }
#     ]
#   },
#   {
#     "topic_name": "Large Language Models (LLMs)",
#     "subsections": [
#       {
#         "sub_title": "Definition",
#         "sub_explanation": "Large Language Models (LLMs) are a type of artificial intelligence model that are trained on massive amounts of text data. They are designed to understand, generate, and manipulate human language. LLMs are characterized by their enormous size (billions or trillions of parameters) and their ability to perform a wide variety of natural language processing tasks."
#       },
#       {
#         "sub_title": "Capabilities",
#         "sub_explanation": "LLMs can perform tasks such as text generation, translation, summarization, question answering, code generation, and creative writing. They learn complex linguistic patterns, grammar, facts, and reasoning abilities from their training data."
#       },
#       {
#         "sub_title": "Underlying Technology",
#         "sub_explanation": "LLMs are typically built using deep learning architectures, most notably the Transformer architecture, which allows them to process sequential data like text very effectively."
#       }
#     ]
#   },
#   {
#     "topic_name": "Relationship Between Machine Learning, Data Centers, and LLMs",
#     "subsections": [
#       {
#         "sub_title": "LLMs as a Product of Machine Learning",
#         "sub_explanation": "LLMs are a sophisticated application and outcome of machine learning research and development. The techniques used to train LLMs, such as deep learning and neural networks, are core machine learning concepts. Therefore, LLMs are a specific, advanced type of machine learning model."
#       },
#       {
#         "sub_title": "Data Centers as the Foundation for LLMs and ML",
#         "sub_explanation": "Training and running LLMs, as well as many other complex machine learning models, requires immense computational power and vast amounts of data storage. Data centers provide the necessary infrastructure – high-performance servers, specialized hardware (like GPUs and TPUs), robust networking, and reliable power – to handle these computationally intensive tasks. Without data centers, it would be practically impossible to develop, train, and deploy LLMs at scale."
#       },
#       {
#         "sub_title": "Interdependence",
#         "sub_explanation": "In essence, machine learning is the field of study and the set of techniques. LLMs are a powerful manifestation of these techniques. Data centers are the physical environments and infrastructure that enable the training, deployment, and operation of both general machine learning models and highly demanding LLMs. LLMs rely on ML principles, and both ML and LLMs rely heavily on the resources provided by data centers."
#       }
#     ]
#   }
# ]

# %%
import json

# Now the response can be parsed to a python object using the JSON dictionary structure loading
structured_resp = json.loads(text_response)
print(structured_resp)
print(type(structured_resp))
# Out:
# [{'topic_name': 'Machine Learning', 'subsections': [{'sub_title': 'Definition', 'sub_explanation': "Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on building systems that can learn from and make decisions based on data. Instead of being explicitly programmed, ML algorithms use statistical techniques to enable systems to 'learn' from data, identify patterns, and make predictions or decisions without human intervention."}, {'sub_title': 'Types of Machine Learning', 'sub_explanation': 'Common types include supervised learning (learning from labeled data), unsupervised learning (finding patterns in unlabeled data), and reinforcement learning (learning through trial and error with rewards and penalties).'}, {'sub_title': 'Applications', 'sub_explanation': 'ML is used in a wide range of applications, such as image recognition, natural language processing, recommendation systems, fraud detection, and medical diagnosis.'}]}, {'topic_name': 'Data Centers', 'subsections': [{'sub_title': 'Definition', 'sub_explanation': 'A data center is a dedicated physical facility that an organization uses to house its critical IT infrastructure, including servers, storage systems, networking equipment, and related components. These facilities are designed to provide a secure, reliable, and controlled environment for computing operations.'}, {'sub_title': 'Key Components', 'sub_explanation': 'Essential components include servers, storage devices, network switches and routers, power supplies (including UPS and generators), cooling systems (HVAC), and physical security measures.'}, {'sub_title': 'Purpose', 'sub_explanation': 'Data centers serve as the central hub for data storage, processing, and management, enabling businesses to run applications, host websites, and manage their digital operations.'}]}, {'topic_name': 'Large Language Models (LLMs)', 'subsections': [{'sub_title': 'Definition', 'sub_explanation': 'Large Language Models (LLMs) are a type of artificial intelligence model that are trained on massive amounts of text data. They are designed to understand, generate, and manipulate human language. LLMs are characterized by their enormous size (billions or trillions of parameters) and their ability to perform a wide variety of natural language processing tasks.'}, {'sub_title': 'Capabilities', 'sub_explanation': 'LLMs can perform tasks such as text generation, translation, summarization, question answering, code generation, and creative writing. They learn complex linguistic patterns, grammar, facts, and reasoning abilities from their training data.'}, {'sub_title': 'Underlying Technology', 'sub_explanation': 'LLMs are typically built using deep learning architectures, most notably the Transformer architecture, which allows them to process sequential data like text very effectively.'}]}, {'topic_name': 'Relationship Between Machine Learning, Data Centers, and LLMs', 'subsections': [{'sub_title': 'LLMs as a Product of Machine Learning', 'sub_explanation': 'LLMs are a sophisticated application and outcome of machine learning research and development. The techniques used to train LLMs, such as deep learning and neural networks, are core machine learning concepts. Therefore, LLMs are a specific, advanced type of machine learning model.'}, {'sub_title': 'Data Centers as the Foundation for LLMs and ML', 'sub_explanation': 'Training and running LLMs, as well as many other complex machine learning models, requires immense computational power and vast amounts of data storage. Data centers provide the necessary infrastructure – high-performance servers, specialized hardware (like GPUs and TPUs), robust networking, and reliable power – to handle these computationally intensive tasks. Without data centers, it would be practically impossible to develop, train, and deploy LLMs at scale.'}, {'sub_title': 'Interdependence', 'sub_explanation': 'In essence, machine learning is the field of study and the set of techniques. LLMs are ...
# <class 'list'>

# %%
# So now we have an object that we can explore/use in a pythonic way for our purposes
for topic in structured_resp:
    print(topic["topic_name"], "\n")
    # We can access each subsection as well
    for subsection in topic["subsections"]:
        print("\t", subsection["sub_title"], "\n")
        print("\t\t", subsection["sub_explanation"], "\n")
# Out:
# Machine Learning
#
# 	 Definition
#
# 		 Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on building systems that can learn from and make decisions based on data. Instead of being explicitly programmed, ML algorithms use statistical techniques to enable systems to 'learn' from data, identify patterns, and make predictions or decisions without human intervention.
#
# 	 Types of Machine Learning
#
# 		 Common types include supervised learning (learning from labeled data), unsupervised learning (finding patterns in unlabeled data), and reinforcement learning (learning through trial and error with rewards and penalties).
#
# 	 Applications
#
# 		 ML is used in a wide range of applications, such as image recognition, natural language processing, recommendation systems, fraud detection, and medical diagnosis.
#
# Data Centers
#
# 	 Definition
#
# 		 A data center is a dedicated physical facility that an organization uses to house its critical IT infrastructure, including servers, storage systems, networking equipment, and related components. These facilities are designed to provide a secure, reliable, and controlled environment for computing operations.
#
# 	 Key Components
#
# 		 Essential components include servers, storage devices, network switches and routers, power supplies (including UPS and generators), cooling systems (HVAC), and physical security measures.
#
# 	 Purpose
#
# 		 Data centers serve as the central hub for data storage, processing, and management, enabling businesses to run applications, host websites, and manage their digital operations.
#
# Large Language Models (LLMs)
#
# 	 Definition
#
# 		 Large Language Models (LLMs) are a type of artificial intelligence model that are trained on massive amounts of text data. They are designed to understand, generate, and manipulate human language. LLMs are characterized by their enormous size (billions or trillions of parameters) and their ability to perform a wide variety of natural language processing tasks.
#
# 	 Capabilities
#
# 		 LLMs can perform tasks such as text generation, translation, summarization, question answering, code generation, and creative writing. They learn complex linguistic patterns, grammar, facts, and reasoning abilities from their training data.
#
# 	 Underlying Technology
#
# 		 LLMs are typically built using deep learning architectures, most notably the Transformer architecture, which allows them to process sequential data like text very effectively.
#
# Relationship Between Machine Learning, Data Centers, and LLMs
#
# 	 LLMs as a Product of Machine Learning
#
# 		 LLMs are a sophisticated application and outcome of machine learning research and development. The techniques used to train LLMs, such as deep learning and neural networks, are core machine learning concepts. Therefore, LLMs are a specific, advanced type of machine learning model.
#
# 	 Data Centers as the Foundation for LLMs and ML
#
# 		 Training and running LLMs, as well as many other complex machine learning models, requires immense computational power and vast amounts of data storage. Data centers provide the necessary infrastructure – high-performance servers, specialized hardware (like GPUs and TPUs), robust networking, and reliable power – to handle these computationally intensive tasks. Without data centers, it would be practically impossible to develop, train, and deploy LLMs at scale.
#
# 	 Interdependence
#
# 		 In essence, machine learning is the field of study and the set of techniques. LLMs are a powerful manifestation of these techniques. Data centers are the physical environments and infrastructure that enable the training, deployment, and operation of both general machine learning models and highly demanding LLMs. LLMs rely on ML principles, and both ML and LLMs rely heavily on the resources provided by data centers.

# %% [markdown]
# ##### **>>> Exercise 2 (Take home):**
#
# Try a prompt with your own schema structure, it needs to be completely different to the example. It should show an intuitive way to represent the text output of the model based on the prompt you chose. See the documentation for reference: https://ai.google.dev/gemini-api/docs/structured-output

# %%
from pydantic import BaseModel

# Legal Analysis  & Case Brief
from pydantic import BaseModel
from typing import List, Optional, Literal

# Party
class Party(BaseModel):
    name: str
    role: Literal[
        "Plaintiff",
        "Defendant",
        "Appellant",
        "Appellee",
        "Petitioner",
        "Respondent",
        "Other",
    ]
    description: Optional[str] = None

# Issue
class LegalIssue(BaseModel):
    issue_id: int
    issue_question: str
    area_of_law: Optional[str] = None

# Rule
class LegalRule(BaseModel):
    rule_id: int
    source: str
    citation: Optional[str] = None
    rule_text: str

# Holding
class Holding(BaseModel):
    issue_id: int
    holding_text: str

# Reasoning
class ReasoningStep(BaseModel):
    issue_id: int
    step_summary: str
    key_factors: List[str]

# Case Brief
class CaseBrief(BaseModel):
    case_name: str
    citation: str
    court: str
    jurisdiction: str
    decision_year: int
    docket_number: Optional[str] = None

    parties: List[Party]
    procedural_posture: str

    material_facts: List[str]

    issues: List[LegalIssue]
    rules: List[LegalRule]
    holdings: List[Holding]
    reasoning: List[ReasoningStep]

    disposition: str
    notes_for_class: Optional[List[str]] = None

# %%
input_prompt = [
    """
    You are a lawyer in U.S. Read the following case citation and produce a structured case brief following the given schema.
    Focus on one main case, summarizing material facts, legal issues, rules, holdings, reasoning, and disposition in a concise way.
    The Case cittion is '204 Mich. 459, 170 N.W. 668 (1919).'
    """
]
text_response = prompt_gemini(input_prompt = input_prompt, schema = list[CaseBrief])
print(text_response)
# Out:
# [
#   {
#     "case_name": "People v. Smith",
#     "citation": "204 Mich. 459, 170 N.W. 668",
#     "court": "Supreme Court of Michigan",
#     "jurisdiction": "Michigan",
#     "decision_year": 1919,
#     "docket_number": null,
#     "parties": [
#       {
#         "name": "People of the State of Michigan",
#         "role": "Plaintiff"
#       },
#       {
#         "name": "George Smith",
#         "role": "Defendant"
#       }
#     ],
#     "procedural_posture": "Appeal from a conviction for violation of the liquor law.",
#     "material_facts": [
#       "The defendant, George Smith, was charged with selling intoxicating liquors without a license.",
#       "Evidence was presented that the defendant sold a bottle of whiskey to a witness.",
#       "The defense argued that the sale was made by an employee and not by the defendant personally.",
#       "The trial court instructed the jury that the defendant was liable for the acts of his employee."
#     ],
#     "issues": [
#       {
#         "issue_id": 1,
#         "issue_question": "Is a principal liable for the illegal sale of intoxicating liquor by an employee, even if the principal did not personally participate in the sale?",
#         "area_of_law": "Criminal Law, Agency"
#       }
#     ],
#     "rules": [
#       {
#         "rule_id": 1,
#         "source": "Michigan Compiled Laws",
#         "citation": "Comp. Laws 1915, § 7079",
#         "rule_text": "Any person who shall sell any intoxicating liquors contrary to the provisions of this act shall be guilty of a misdemeanor."
#       },
#       {
#         "rule_id": 2,
#         "source": "Common Law Principles of Agency",
#         "citation": null,
#         "rule_text": "A principal is generally liable for the acts of their agent if the acts are within the scope of the agent's employment."
#       }
#     ],
#     "holdings": [
#       {
#         "issue_id": 1,
#         "holding_text": "Yes, a principal is liable for the illegal sale of intoxicating liquor by an employee, even if the principal did not personally participate in the sale, as the employee is acting as the principal's agent."
#       }
#     ],
#     "reasoning": [
#       {
#         "issue_id": 1,
#         "step_summary": "The court affirmed the conviction, holding that the defendant was responsible for the actions of his employee in selling liquor.",
#         "key_factors": [
#           "The employee was acting within the scope of his employment when making the sale.",
#           "The statute prohibiting the sale of liquor is intended to hold the proprietor responsible for all sales made on the premises.",
#           "The law does not require personal participation by the owner in every illegal sale to establish guilt."
#         ]
#       }
#     ],
#     "disposition": "Affirmed.",
#     "notes_for_class": [
#       "This case establishes strict liability for business owners regarding illegal sales made by their employees.",
#       "It highlights the principle that employers are responsible for the actions of their agents within the scope of employment, particularly in regulatory contexts like liquor sales."
#     ]
#   }
# ]

# %%
import json
structured_resp = json.loads(text_response)
print(type(structured_resp))
print(structured_resp)
# Out:
# <class 'list'>
# [{'case_name': 'People v. Smith', 'citation': '204 Mich. 459, 170 N.W. 668', 'court': 'Supreme Court of Michigan', 'jurisdiction': 'Michigan', 'decision_year': 1919, 'docket_number': None, 'parties': [{'name': 'People of the State of Michigan', 'role': 'Plaintiff'}, {'name': 'George Smith', 'role': 'Defendant'}], 'procedural_posture': 'Appeal from a conviction for violation of the liquor law.', 'material_facts': ['The defendant, George Smith, was charged with selling intoxicating liquors without a license.', 'Evidence was presented that the defendant sold a bottle of whiskey to a witness.', 'The defense argued that the sale was made by an employee and not by the defendant personally.', 'The trial court instructed the jury that the defendant was liable for the acts of his employee.'], 'issues': [{'issue_id': 1, 'issue_question': 'Is a principal liable for the illegal sale of intoxicating liquor by an employee, even if the principal did not personally participate in the sale?', 'area_of_law': 'Criminal Law, Agency'}], 'rules': [{'rule_id': 1, 'source': 'Michigan Compiled Laws', 'citation': 'Comp. Laws 1915, § 7079', 'rule_text': 'Any person who shall sell any intoxicating liquors contrary to the provisions of this act shall be guilty of a misdemeanor.'}, {'rule_id': 2, 'source': 'Common Law Principles of Agency', 'citation': None, 'rule_text': "A principal is generally liable for the acts of their agent if the acts are within the scope of the agent's employment."}], 'holdings': [{'issue_id': 1, 'holding_text': "Yes, a principal is liable for the illegal sale of intoxicating liquor by an employee, even if the principal did not personally participate in the sale, as the employee is acting as the principal's agent."}], 'reasoning': [{'issue_id': 1, 'step_summary': 'The court affirmed the conviction, holding that the defendant was responsible for the actions of his employee in selling liquor.', 'key_factors': ['The employee was acting within the scope of his employment when making the sale.', 'The statute prohibiting the sale of liquor is intended to hold the proprietor responsible for all sales made on the premises.', 'The law does not require personal participation by the owner in every illegal sale to establish guilt.']}], 'disposition': 'Affirmed.', 'notes_for_class': ['This case establishes strict liability for business owners regarding illegal sales made by their employees.', 'It highlights the principle that employers are responsible for the actions of their agents within the scope of employment, particularly in regulatory contexts like liquor sales.']}]

# %%
for case in structured_resp:
  print("Case name:", case["case_name"], "\n")
  print("Citation:", case["citation"])
  print("Court:", case["court"])
  print("Disposition:", case["disposition"])
  print()

  # Facts
  print("Material facts:")
  for fact in case["material_facts"]:
    print("  -", fact)
  print()

  # Issues
  print("Issues:")
  for issue in case["issues"]:
    print(f"  [Issue {issue['issue_id']}] {issue['issue_question']}")
    if issue.get("area_of_law"):
      print("     Area of law:", issue["area_of_law"])
  print()

  # Holdings
  print("Holdings:")
  for holding in case["holdings"]:
    print(f"  (Issue {holding['issue_id']}) {holding['holding_text']}")
  print()

  # Reasoning
  print("Reasoning:")
  for step in case["reasoning"]:
    print(f"  - Issue {step['issue_id']}: {step['step_summary']}")
    if step.get("key_factors"):
      print("      Key factors:")
      for f in step["key_factors"]:
        print("        *", f)
  print("=" * 60)
  print() # Impressive!
# Out:
# Case name: People v. Smith
#
# Citation: 204 Mich. 459, 170 N.W. 668
# Court: Supreme Court of Michigan
# Disposition: Affirmed.
#
# Material facts:
#   - The defendant, George Smith, was charged with selling intoxicating liquors without a license.
#   - Evidence was presented that the defendant sold a bottle of whiskey to a witness.
#   - The defense argued that the sale was made by an employee and not by the defendant personally.
#   - The trial court instructed the jury that the defendant was liable for the acts of his employee.
#
# Issues:
#   [Issue 1] Is a principal liable for the illegal sale of intoxicating liquor by an employee, even if the principal did not personally participate in the sale?
#      Area of law: Criminal Law, Agency
#
# Holdings:
#   (Issue 1) Yes, a principal is liable for the illegal sale of intoxicating liquor by an employee, even if the principal did not personally participate in the sale, as the employee is acting as the principal's agent.
#
# Reasoning:
#   - Issue 1: The court affirmed the conviction, holding that the defendant was responsible for the actions of his employee in selling liquor.
#       Key factors:
#         * The employee was acting within the scope of his employment when making the sale.
#         * The statute prohibiting the sale of liquor is intended to hold the proprietor responsible for all sales made on the premises.
#         * The law does not require personal participation by the owner in every illegal sale to establish guilt.
# ============================================================

# %% [markdown]
# ---
# ### **2.3 Information Extraction and Grounding:**
#
# `NOTE: This whole section including the exercise is now considered a bonus section, not counted for the main grade.`
#
# When using LLMs to extract structured data from text, two main challenges arise:
#
# 1.  **Trust:** LLMs can "hallucinate" or invent information. We need to ensure the extracted data is accurate and comes directly from the source text.
# 2.  **Scalability:** We need a reliable way to extract complex information consistently from thousands of large, messy documents.
#
# The solution to these challenges is **grounding**—the process of linking every piece of extracted data back to its specific origin in the source document. This creates a verifiable audit trail, building trust in the output.

# %% [markdown]
# ---
# #### **`langextract`: A Library for Grounded Extraction**
#
# **`langextract`** is an open-source Python library from Google designed to create trustworthy data extraction pipelines. It uses LLMs to convert unstructured text into structured data with a focus on reliability and traceability.
#
# **Key Features:**
#
# *   **Precise Grounding:** Its core feature. It maps every extracted item to its exact character position in the original text, allowing for easy verification.
# *   **Reliable Structured Output:** Uses examples (few-shot prompting) to ensure the LLM's output consistently follows a predefined format.
# *   **Adaptable & No Fine-Tuning:** Can be adapted to any domain (e.g., legal, medical) simply by changing the examples and instructions, without needing to retrain a model.
# *   **Handles Long Documents:** Built to process lengthy texts that might exceed an LLM's standard context window.
# *   **Flexible LLM Support:** It is model-agnostic and works with various LLMs like Gemini, OpenAI models, and even local open-source models through Ollama.
#
# **`Github repository:`** [langextract](https://github.com/google/langextract)

# %% [markdown]
# ---
#
# ##### **2.3.1 Using PDF Documents:**
#
# For PDF Document information extraction we are going to use the `pymupdf` library. Documentation: [pymupdf](https://pymupdf.readthedocs.io/en/latest/)
#
# And then we are going to pass it on to langextract to get insights on the document's content.
#
# We can also process documents using Gemini, for more information you can check their documentation: [Document Understanding](https://ai.google.dev/gemini-api/docs/document-processing)

# %%
import pymupdf
# Extract text from the PDF and format it for the prompt
# This is a review from the movie interstellar
pdf_path = "./DM2025-Lab2-Exercise/data/documents/doc_example_review_interstellar.pdf"
formatted_text = ""
try:
    doc = pymupdf.open(pdf_path)
    # In case the PDF documents have more than one page, in this example it only has one
    for i, page in enumerate(doc):
        text = page.get_text("text")
        # Format follows the prompt's requirement: **Page X** """document's text"""
        formatted_text += f'**Page {i + 1}**\n'
        formatted_text += f'"""\n{text.strip()}\n"""\n\n'
    doc.close()
    print(f"✓ Extracted text from '{pdf_path}'")
except Exception as e:
    print(f"Could not read PDF: {e}")
    formatted_text = "Error: Could not process PDF file."
# Out:
# ✓ Extracted text from './DM2025-Lab2-Exercise/data/documents/doc_example_review_interstellar.pdf'

# %%
print(formatted_text)
# Out:
# **Page 1**
# """
# Dan Baldwin
# Group 4
# Auteur Review - Interstellar
# I believe Christopher Nolan: the director behind the 2014 sci-ﬁ/adventure cinematic ‘Interstellar,’
# to be a very intellectual and imaginative inventive talent.
# His style in his previous ﬁlms sets characters in epic unique locations, with gargantuan issues to
# face, and artistically impresses the audience with how the characters solve their problems. For
# example, in Nolan’s 2010 ﬁlm ‘Inception,’ he tackles the idea of dreams, and sets his characters
# diving through dreams within dreams within even more dreams to complete their goals. Because
# this idea is so farfetched, and dreams are a subject in which science has made little factual
# discovery in, Nolan is free to use his creativity to present ideas such as landscapes folding in on
# themselves and corridors spinning, without seeming unrealistic.
# This brain-racking epic theme is once again evident in ‘Interstellar,’ as Nolan sets his characters
# during a second American dust bowl on future Earth. The world is short of food, and will soon be
# uninhabitable. So, ex-NASA pilot ‘Cooper’ (Matthew McConaughey) is summoned back to space
# travel in a bid to ﬁnd a new planet for the species to inhabit. Luckily for Cooper and his team, a
# black hole orbiting Saturn can transport them further into space to land on these potential
# planets.
# Throughout the ﬂick, the crew explore multiple worlds - again feeding Nolan’s mind more
# opportunities to create crazy scenarios. For example, one planet that Cooper and his friends,
# ‘Brand,’ (Anne Hathaway) and ‘Romilly,’ (David Gyasi) visit initially seems like an inﬁnite sea of two
# feet deep water. Not threatening at all right? Well think again, because the crew suddenly ﬁnd out
# that a giant 100ft tidal wave is about to hit them, and they have minutes to ﬂy away. Nolan further
# increases the stakes in this scene as it is explained that every hour spent on this planet counts for
# seven years on earth, meaning the planet will be destroyed before they return if their ship sinks.
# At the climax of the ﬁlm, the crew end up sending themselves through a black hole into a
# tesseract (a 3D representation of a larger dimension) to ﬁnd the ‘secret to harnessing gravity’
# which will let the human race bend space-time in order to survive oﬀ earth. I know. Mental.
# The imagination that Nolan possesses and implicates into ‘Interstellar’ is farfetched and
# wonderful, not only impressing his audience with the appealing visuals he creates, but induces
# them to think and discuss what is going on due its scientiﬁc depth. Personally, as someone who is
# bamboozled by the idea of how big the universe is, I ﬁnd it unendingly entertaining to repeatedly
# watch this ﬁlm and understanding it more each time, and can only hope the technology portrayed
# will one day come true.
# Overall, ‘Interstellar’ is a clear example of Nolan’s auteur talent, as he once again ﬁgments yet
# another cluster of conditions for us to marvel at. With a fantastic score from world famous
# composer Hanz Zimmer, his epic, orchestral theme sets the audience in the palm of his hands as
# we stress over how we are all going to be saved once again.
# """

# %% [markdown]
# We define our prompt and examples based on our required type of data, in this case we are going to do it having `movie reviews` in mind.

# %%
import langextract as lx
import textwrap

# Defining the extraction prompt for "movie review" type of data
prompt = textwrap.dedent("""\
    Extract specific opinions and their impact on the audience from this movie review.
    Important: Use exact text verbatim from the input for extraction_text. Do not paraphrase.
    Extract entities in order of appearance with no overlapping text spans.

    Use the 'opinion_statement' class for direct judgments about film elements (like plot, score, or acting).
    - 'subject' should be the element being reviewed.
    - 'sentiment' should be Positive, Negative, or Neutral.
    - 'key_phrase' should be the core descriptive words.

    Use the 'audience_impact' class for phrases describing the effect on the viewer.
    - 'emotion_evoked' should be the feeling or reaction (e.g., stress, joy, confusion).
    - 'causal_element' is what part of the film caused the reaction.
    - 'target_audience' is who was affected (e.g., 'the audience', 'the reviewer').
    """)

# Providing high-quality examples to guide the model
# These examples show the model exactly how to differentiate between the two classes
examples = [
    # Example 1: Demonstrates a positive opinion on the plot and its direct impact on the reviewer
    lx.data.ExampleData(
        text="The film boasts a truly clever plot that kept me guessing until the very end.",
        extractions=[
            lx.data.Extraction(
                extraction_class="opinion_statement",
                extraction_text="a truly clever plot",
                attributes={
                    "subject": "The plot",
                    "sentiment": "Positive",
                    "key_phrase": "truly clever"
                }
            ),
            lx.data.Extraction(
                extraction_class="audience_impact",
                extraction_text="kept me guessing until the very end",
                attributes={
                    "emotion_evoked": ["engaged", "curious"],
                    "causal_element": "The plot",
                    "target_audience": "the reviewer"
                }
            ),
        ]
    ),
    # Example 2: Shows a negative opinion and a separate audience impact caused by the soundtrack
    lx.data.ExampleData(
        text="Unfortunately, the dialogue felt clunky and unnatural, and the jarring soundtrack made the audience jump.",
        extractions=[
            lx.data.Extraction(
                extraction_class="opinion_statement",
                extraction_text="the dialogue felt clunky and unnatural",
                attributes={
                    "subject": "The dialogue",
                    "sentiment": "Negative",
                    "key_phrase": "clunky and unnatural"
                }
            ),
            lx.data.Extraction(
                extraction_class="audience_impact",
                extraction_text="made the audience jump",
                attributes={
                    "emotion_evoked": ["startled", "on edge"],
                    "causal_element": "The soundtrack",
                    "target_audience": "the audience"
                }
            )
        ]
    )
]

# %% [markdown]
# Here we define our main function to call for langextract information extraction, note that there are some constants in the functions that we are not going to change for the example but it would be required to explore and understand in the exercise. In this function we obtain the resulting raw extracted information into a .jsonl file and the visualization into a .html file. Check the documentation for more information.
#
# The files will be saved in the following directory: `results/info_extractions`

# %%
import os
import langextract as lx

# We define our main langextract function
def grounded_info_extraction(input_documents, prompt, examples, file_name, model_id ="gemini-2.5-flash-lite", extraction_passes = 1, max_workers = 5, max_char_buffer = 2000):
    result = lx.extract(
        text_or_documents=input_documents,
        prompt_description=prompt,
        examples=examples,
        model_id=model_id,
        extraction_passes=extraction_passes,    # Improves recall through multiple passes over the same text, needs temperature above 0.0
        max_workers=max_workers,         # Parallel processing for speed, remember there are API call rate limits, so do not abuse
        max_char_buffer=max_char_buffer    # Smaller contexts for better accuracy, currently: 1000 characters per batch
    )

    # Display results
    print(f"Extracted {len(result.extractions)} entities:\n")
    for extraction in result.extractions:
        print(f"• {extraction.extraction_class}: '{extraction.extraction_text}'")
        if extraction.attributes:
            for key, value in extraction.attributes.items():
                print(f"  - {key}: {value}")

    output_dir = "./DM2025-Lab2-Exercise/results/info_extractions"
    os.makedirs(output_dir, exist_ok=True)
    # Save results to JSONL
    lx.io.save_annotated_documents([result], output_name=f"{file_name}.jsonl", output_dir=output_dir)

    # Generate interactive visualization
    html_content = lx.visualize(f"{output_dir}/{file_name}.jsonl")
    with open(f"{output_dir}/{file_name}_vis.html", "w") as f:
        if hasattr(html_content, 'data'):
            f.write(html_content.data)
        else:
            f.write(html_content)

    print(f"✓ Visualization saved to {output_dir}/{file_name}_vis.html")

    # returning html content for display
    return html_content

# %%
html_content = grounded_info_extraction(formatted_text, prompt, examples, "review_extraction_example")
# Out:
# WARNING:google_genai._api_client:Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Extracted 13 entities:
#
# • opinion_statement: 'a very intellectual and imaginative inventive talent'
#   - subject: Christopher Nolan
#   - sentiment: Positive
#   - key_phrase: very intellectual and imaginative inventive talent
# • opinion_statement: 'artistically impresses the audience'
#   - subject: Nolan's style
#   - sentiment: Positive
#   - key_phrase: artistically impresses
# • opinion_statement: 'This brain-racking epic theme is once again evident in ‘Interstellar,’'
#   - subject: The theme
#   - sentiment: Positive
#   - key_phrase: brain-racking epic theme
# • opinion_statement: 'crazy scenarios'
#   - subject: Nolan's mind
#   - sentiment: Positive
#   - key_phrase: crazy
# • opinion_statement: 'Not threatening at all right?'
#   - subject: The planet
#   - sentiment: Neutral
#   - key_phrase: Not threatening at all
# • opinion_statement: 'a giant 100ft tidal wave is about to hit them'
#   - subject: The tidal wave
#   - sentiment: Negative
#   - key_phrase: giant 100ft tidal wave
# • audience_impact: 'minutes to ﬂy away'
#   - emotion_evoked: ['stress', 'urgency']
#   - causal_element: The tidal wave
#   - target_audience: the crew
# • opinion_statement: 'farfetched and wonderful'
#   - subject: The imagination that Nolan possesses and implicates into ‘Interstellar’
#   - sentiment: Positive
#   - key_phrase: farfetched and wonderful
# • audience_impact: 'not only impressing his audience with the appealing visuals he creates, but induces them to think and discuss what is going on due its scientiﬁc depth'
#   - emotion_evoked: ['impressed', 'thoughtful', 'engaged']
#   - causal_element: The appealing visuals and scientific depth
#   - target_audience: his audience
# • audience_impact: 'I ﬁnd it unendingly entertaining to repeatedly watch this ﬁlm and understanding it more each time'
#   - emotion_evoked: ['entertained', 'intellectually stimulated']
#   - causal_element: The film's complexity and depth
#   - target_audience: the reviewer
# • opinion_statement: 'a clear example of Nolan’s auteur talent'
#   - subject: ‘Interstellar’
#   - sentiment: Positive
#   - key_phrase: clear example of Nolan’s auteur talent
# • opinion_statement: 'fantastic score'
#   - subject: The score
#   - sentiment: Positive
#   - key_phrase: fantastic
# • audience_impact: 'sets the audience in the palm of his hands as we stress over how we are all going to be saved once again'
#   - emotion_evoked: ['captivated', 'stressed']
#   - causal_element: His epic, orchestral theme
#   - target_audience: the audience
# LangExtract: Saving to review_extraction_example.jsonl: 1 docs [00:00, 387.86 docs/s]
# ✓ Saved 1 documents to review_extraction_example.jsonl
# LangExtract: Loading review_extraction_example.jsonl: 100%|██████████| 8.58k/8.58k [00:00<00:00, 9.21MB/s]
# ✓ Loaded 1 documents from review_extraction_example.jsonl
# ✓ Visualization saved to ./DM2025-Lab2-Exercise/results/info_extractions/review_extraction_example_vis.html

# %%
import json
# We can also observe the structure of the raw extracted data
with open("./DM2025-Lab2-Exercise/results/info_extractions/review_extraction_example.jsonl", "r") as f:
    content_extracted_raw = json.load(f)
content_extracted_raw
# Out:
# {'extractions': [{'extraction_class': 'opinion_statement',
#    'extraction_text': 'a very intellectual and imaginative inventive talent',
#    'char_interval': {'start_pos': 172, 'end_pos': 224},
#    'alignment_status': 'match_exact',
#    'extraction_index': 1,
#    'group_index': 0,
#    'description': None,
#    'attributes': {'subject': 'Christopher Nolan',
#     'sentiment': 'Positive',
#     'key_phrase': 'very intellectual and imaginative inventive talent'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'artistically impresses the audience',
#    'char_interval': {'start_pos': 338, 'end_pos': 373},
#    'alignment_status': 'match_exact',
#    'extraction_index': 2,
#    'group_index': 1,
#    'description': None,
#    'attributes': {'subject': "Nolan's style",
#     'sentiment': 'Positive',
#     'key_phrase': 'artistically impresses'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'This brain-racking epic theme is once again evident in ‘Interstellar,’',
#    'char_interval': {'start_pos': 878, 'end_pos': 948},
#    'alignment_status': 'match_exact',
#    'extraction_index': 3,
#    'group_index': 2,
#    'description': None,
#    'attributes': {'subject': 'The theme',
#     'sentiment': 'Positive',
#     'key_phrase': 'brain-racking epic theme'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'crazy scenarios',
#    'char_interval': {'start_pos': 1484, 'end_pos': 1499},
#    'alignment_status': 'match_exact',
#    'extraction_index': 4,
#    'group_index': 3,
#    'description': None,
#    'attributes': {'subject': "Nolan's mind",
#     'sentiment': 'Positive',
#     'key_phrase': 'crazy'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Not threatening at all right?',
#    'char_interval': {'start_pos': 1676, 'end_pos': 1705},
#    'alignment_status': 'match_exact',
#    'extraction_index': 5,
#    'group_index': 4,
#    'description': None,
#    'attributes': {'subject': 'The planet',
#     'sentiment': 'Neutral',
#     'key_phrase': 'Not threatening at all'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'a giant 100ft tidal wave is about to hit them',
#    'char_interval': {'start_pos': 1764, 'end_pos': 1809},
#    'alignment_status': 'match_exact',
#    'extraction_index': 6,
#    'group_index': 5,
#    'description': None,
#    'attributes': {'subject': 'The tidal wave',
#     'sentiment': 'Negative',
#     'key_phrase': 'giant 100ft tidal wave'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'minutes to ﬂy away',
#    'char_interval': {'start_pos': 1825, 'end_pos': 1843},
#    'alignment_status': 'match_exact',
#    'extraction_index': 7,
#    'group_index': 6,
#    'description': None,
#    'attributes': {'emotion_evoked': ['stress', 'urgency'],
#     'causal_element': 'The tidal wave',
#     'target_audience': 'the crew'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'farfetched and wonderful',
#    'char_interval': {'start_pos': 2418, 'end_pos': 2443},
#    'alignment_status': 'match_exact',
#    'extraction_index': 1,
#    'group_index': 0,
#    'description': None,
#    'attributes': {'subject': 'The imagination that Nolan possesses and implicates into ‘Interstellar’',
#     'sentiment': 'Positive',
#     'key_phrase': 'farfetched and wonderful'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'not only impressing his audience with the appealing visuals he creates, but induces them to think and discuss what is going on due its scientiﬁc depth',
#    'char_interval': {'start_pos': 2445, 'end_pos': 2596},
#    'alignment_status': 'match_exact',
#    'extraction_index': 2,
#    'group_index': 1,
#    'description': None,
#    'attributes': {'emotion_evoked': ['impressed', 'thoughtful', 'engaged'],
#     'causal_element': 'The appealing visuals and scientific depth',
#     'target_audience': 'his audience'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'I ﬁnd it unendingly entertaining to repeatedly watch this ﬁlm and understanding it more each time',
#    'char_interval': {'start_pos': 2680, 'end_pos': 2778},
#    'alignment_status': 'match_exact',
#    'extraction_index': 3,
#    'group_index': 2,
#    'description': None,
#    'attributes': {'emotion_evoked': ['entertained',
#      'intellectually stimulated'],
#     'causal_element': "The film's complexity and depth",
#     'target_audience': 'the reviewer'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'a clear example of Nolan’s auteur talent',
#    'char_interval': {'start_pos': 2876, 'end_pos': 2916},
#    'alignment_status': 'match_exact',
#    'extraction_index': 4,
#    'group_index': 3,
#    'description': None,
#    'attributes': {'subject': '‘Interstellar’',
#     'sentiment': 'Positive',
#     'key_phrase': 'clear example of Nolan’s auteur talent'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'fantastic score',
#    'char_interval': {'start_pos': 3006, 'end_pos': 3021},
#    'alignment_status': 'match_exact',
#    'extraction_index': 5,
#    'group_index': 4,
#    'description': None,
#    'attributes': {'subject': 'The score',
#     'sentiment': 'Positive',
#     'key_phrase': 'fantastic'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'sets the audience in the palm of his hands as we stress over how we are all going to be saved once again',
#    'char_interval': {'start_pos': 3090, 'end_pos': 3195},
#    'alignment_status': 'match_exact',
#    'extraction_index': 6,
#    'group_index': 5,
#    'description': None,
#    'attributes': {'emotion_evoked': ['captivated', 'stressed'],
#     'causal_element': 'His epic, orchestral theme',
#     'target_audience': 'the audience'}}],
#  'text': '**Page 1**\n"""\nDan Baldwin\nGroup 4\nAuteur Review - Interstellar \nI believe Christopher Nolan: the director behind the 2014 sci-ﬁ/adventure cinematic ‘Interstellar,’ \nto be a very intellectual and imaginative inventive talent.  \nHis style in his previous ﬁlms sets characters in epic unique locations, with gargantuan issues to \nface, and artistically impresses the audience with how the characters solve their problems. For \nexample, in Nolan’s 2010 ﬁlm ‘Inception,’ he tackles the idea of dreams, and sets his characters \ndiving through dreams within dreams within even more dreams to complete their goals. Because \nthis idea is so farfetched, and dreams are a subject in which science has made little factual \ndiscovery in, Nolan is free to use his creativity to present ideas such as landscapes folding in on \nthemselves and corridors spinning, without seeming unrealistic. \nThis brain-racking epic theme is once again evident in ‘Interstellar,’ as Nolan sets his characters \nduring a second American dust bowl on future Earth. The world is short of food, and will soon be \nuninhabitable. So, ex-NASA pilot ‘Cooper’ (Matthew McConaughey) is summoned back to space \ntravel in a bid to ﬁnd a new planet for the species to inhabit. Luckily for Cooper and his team, a \nblack hole orbiting Saturn can transport them further into space to land on these potential \nplanets. \nThroughout the ﬂick, the crew explore multiple worlds - again feeding Nolan’s mind more \nopportunities to create crazy scenarios. For example, one planet that Cooper and his friends, \n‘Brand,’ (Anne Hathaway) and ‘Romilly,’ (David Gyasi) visit initially seems like an inﬁnite sea of two \nfeet deep water. Not threatening at all right? Well think again, because the crew suddenly ﬁnd out \nthat a giant 100ft tidal wave is about to hit them, and they have minutes to ﬂy away. Nolan further \nincreases the stakes in this scene as it is explained that every hour spent on this planet counts for \nseven years on earth, meaning the planet will be destroyed before they return if their ship sinks. \nAt the climax of the ﬁlm, the crew end up sending themselves through a black hole into a \ntesseract (a 3D representation of a larger dimension) to ﬁnd the ‘secret to harnessing gravity’ \nwhich will let the human race bend space-time in order to survive oﬀ earth. I know. Mental. \nThe imagination that Nolan possesses and implicates into ‘Interstellar’ is farfetched and \nwonderful, not only impressing his audience with the appealing visuals he creates, but induces \nthem to think and discuss what is going on due its scientiﬁc depth. Personally, as someone who is \nbamboozled by the idea of how big the universe is, I ﬁnd it unendingly entertaining to repeatedly \nwatch this ﬁlm and understanding it more each time, and can only hope the technology portrayed \nwill one day come true. \nOverall, ‘Interstellar’ is a clear example of Nolan’s auteur talent, as he once again ﬁgments yet \nanother cluster of conditions for us to marvel at. With a fantastic score from world famous \ncomposer Hanz Zimmer, his epic, orchestral theme sets the audience in the palm of his hands as \nwe stress over how we are all going to be saved once again.\n"""\n\n',
#  'document_id': 'doc_cd698a5a'}

# %%
html_content
# Out:
# <style>
# .lx-highlight { position: relative; border-radius:3px; padding:1px 2px;}
# .lx-highlight .lx-tooltip {
#   visibility: hidden;
#   opacity: 0;
#   transition: opacity 0.2s ease-in-out;
#   background: #333;
#   color: #fff;
#   text-align: left;
#   border-radius: 4px;
#   padding: 6px 8px;
#   position: absolute;
#   z-index: 1000;
#   bottom: 125%;
#   left: 50%;
#   transform: translateX(-50%);
#   font-size: 12px;
#   max-width: 240px;
#   white-space: normal;
#   box-shadow: 0 2px 6px rgba(0,0,0,0.3);
# }
# .lx-highlight:hover .lx-tooltip { visibility: visible; opacity:1; }
# .lx-animated-wrapper { max-width: 100%; font-family: Arial, sans-serif; }
# .lx-controls {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 8px;
#   padding: 12px; margin-bottom: 16px;
# }
# .lx-button-row {
#   display: flex; justify-content: center; gap: 8px; margin-bottom: 12px;
# }
# .lx-control-btn {
#   background: #4285f4; color: white; border: none; border-radius: 4px;
#   padding: 8px 16px; cursor: pointer; font-size: 13px; font-weight: 500;
#   transition: background-color 0.2s;
# }
# .lx-control-btn:hover { background: #3367d6; }
# .lx-progress-container {
#   margin-bottom: 8px;
# }
# .lx-progress-slider {
#   width: 100%; margin: 0; appearance: none; height: 6px;
#   background: #ddd; border-radius: 3px; outline: none;
# }
# .lx-progress-slider::-webkit-slider-thumb {
#   appearance: none; width: 18px; height: 18px; background: #4285f4;
#   border-radius: 50%; cursor: pointer;
# }
# .lx-progress-slider::-moz-range-thumb {
#   width: 18px; height: 18px; background: #4285f4; border-radius: 50%;
#   cursor: pointer; border: none;
# }
# .lx-status-text {
#   text-align: center; font-size: 12px; color: #666; margin-top: 4px;
# }
# .lx-text-window {
#   font-family: monospace; white-space: pre-wrap; border: 1px solid #90caf9;
#   padding: 12px; max-height: 260px; overflow-y: auto; margin-bottom: 12px;
#   line-height: 1.6;
# }
# .lx-attributes-panel {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 6px;
#   padding: 8px 10px; margin-top: 8px; font-size: 13px;
# }
# .lx-current-highlight {
#   border-bottom: 4px solid #ff4444;
#   font-weight: bold;
#   animation: lx-pulse 1s ease-in-out;
# }
# @keyframes lx-pulse {
#   0% { text-decoration-color: #ff4444; }
#   50% { text-decoration-color: #ff0000; }
#   100% { text-decoration-color: #ff4444; }
# }
# .lx-legend {
#   font-size: 12px; margin-bottom: 8px;
#   padding-bottom: 8px; border-bottom: 1px solid #e0e0e0;
# }
# .lx-label {
#   display: inline-block;
#   padding: 2px 4px;
#   border-radius: 3px;
#   margin-right: 4px;
#   color: #000;
# }
# .lx-attr-key {
#   font-weight: 600;
#   color: #1565c0;
#   letter-spacing: 0.3px;
# }
# .lx-attr-value {
#   font-weight: 400;
#   opacity: 0.85;
#   letter-spacing: 0.2px;
# }
#
# /* Add optimizations with larger fonts and better readability for GIFs */
# .lx-gif-optimized .lx-text-window { font-size: 16px; line-height: 1.8; }
# .lx-gif-optimized .lx-attributes-panel { font-size: 15px; }
# .lx-gif-optimized .lx-current-highlight { text-decoration-thickness: 4px; }
# </style>
#     <div class="lx-animated-wrapper lx-gif-optimized">
#       <div class="lx-attributes-panel">
#         <div class="lx-legend">Highlights Legend: <span class="lx-label" style="background-color:#D2E3FC;">audience_impact</span> <span class="lx-label" style="background-color:#C8E6C9;">opinion_statement</span></div>
#         <div id="attributesContainer"></div>
#       </div>
#       <div class="lx-text-window" id="textWindow">
#         **Page 1**
# &quot;&quot;&quot;
# Dan Baldwin
# Group 4
# Auteur Review - Interstellar
# I believe Christopher Nolan: the director behind the 2014 sci-ﬁ/adventure cinematic ‘Interstellar,’
# to be <span class="lx-highlight lx-current-highlight" data-idx="0" style="background-color:#C8E6C9;">a very intellectual and imaginative inventive talent</span>.
# His style in his previous ﬁlms sets characters in epic unique locations, with gargantuan issues to
# face, and <span class="lx-highlight" data-idx="1" style="background-color:#C8E6C9;">artistically impresses the audience</span> with how the characters solve their problems. For
# example, in Nolan’s 2010 ﬁlm ‘Inception,’ he tackles the idea of dreams, and sets his characters
# diving through dreams within dreams within even more dreams to complete their goals. Because
# this idea is so farfetched, and dreams are a subject in which science has made little factual
# discovery in, Nolan is free to use his creativity to present ideas such as landscapes folding in on
# themselves and corridors spinning, without seeming unrealistic.
# <span class="lx-highlight" data-idx="2" style="background-color:#C8E6C9;">This brain-racking epic theme is once again evident in ‘Interstellar,’</span> as Nolan sets his characters
# during a second American dust bowl on future Earth. The world is short of food, and will soon be
# uninhabitable. So, ex-NASA pilot ‘Cooper’ (Matthew McConaughey) is summoned back to space
# travel in a bid to ﬁnd a new planet for the species to inhabit. Luckily for Cooper and his team, a
# black hole orbiting Saturn can transport them further into space to land on these potential
# planets.
# Throughout the ﬂick, the crew explore multiple worlds - again feeding Nolan’s mind more
# opportunities to create <span class="lx-highlight" data-idx="3" style="background-color:#C8E6C9;">crazy scenarios</span>. For example, one planet that Cooper and his friends,
# ‘Brand,’ (Anne Hathaway) and ‘Romilly,’ (David Gyasi) visit initially seems like an inﬁnite sea of two
# feet deep water. <span class="lx-highlight" data-idx="4" style="background-color:#C8E6C9;">Not threatening at all right?</span> Well think again, because the crew suddenly ﬁnd out
# that <span class="lx-highlight" data-idx="5" style="background-color:#C8E6C9;">a giant 100ft tidal wave is about to hit them</span>, and they have <span class="lx-highlight" data-idx="6" style="background-color:#D2E3FC;">minutes to ﬂy away</span>. Nolan further
# increases the stakes in this scene as it is explained that every hour spent on this planet counts for
# seven years on earth, meaning the planet will be destroyed before they return if their ship sinks.
# At the climax of the ﬁlm, the crew end up sending themselves through a black hole into a
# tesseract (a 3D representation of a larger dimension) to ﬁnd the ‘secret to harnessing gravity’
# which will let the human race bend space-time in order to survive oﬀ earth. I know. Mental.
# The imagination that Nolan possesses and implicates into ‘Interstellar’ is <span class="lx-highlight" data-idx="7" style="background-color:#C8E6C9;">farfetched and
# wonderful</span>, <span class="lx-highlight" data-idx="8" style="background-color:#D2E3FC;">not only impressing his audience with the appealing visuals he creates, but induces
# them to think and discuss what is going on due its scientiﬁc depth</span>. Personally, as someone who is
# bamboozled by the idea of how big the universe is, <span class="lx-highlight" data-idx="9" style="background-color:#D2E3FC;">I ﬁnd it unendingly entertaining to repeatedly
# watch this ﬁlm and understanding it more each time</span>, and can only hope the technology portrayed
# will one day come true.
# Overall, ‘Interstellar’ is <span class="lx-highlight" data-idx="10" style="background-color:#C8E6C9;">a clear example of Nolan’s auteur talent</span>, as he once again ﬁgments yet
# another cluster of conditions for us to marvel at. With a <span class="lx-highlight" data-idx="11" style="background-color:#C8E6C9;">fantastic score</span> from world famous
# composer Hanz Zimmer, his epic, orchestral theme <span class="lx-highlight" data-idx="12" style="background-color:#D2E3FC;">sets the audience in the palm of his hands as
# we stress over how we are all going to be saved once again</span>.
# &quot;&quot;&quot;
#
#
#       </div>
#       <div class="lx-controls">
#         <div class="lx-button-row">
#           <button class="lx-control-btn" onclick="playPause()">▶️ Play</button>
#           <button class="lx-control-btn" onclick="prevExtraction()">⏮ Previous</button>
#           <button class="lx-control-btn" onclick="ne

# %% [markdown]
# ---
# ##### **>>> Bonus Exercise 3 (Take home):**
#
# `NOTE: This exercise is now considered a bonus one, not counted for the main grade, only as extra points.`
#
# Repeat the steps for information extraction using a different movie reviews.
# 1. Search for movie reviews online and save them in a PDF, we suggest **at least 1 page worth of reviews** like in the example.
# 2. Load the PDF and pass them to langextract to extract information from it.
# 3. Display html with the grounded extracted attributes.
# 4. Discuss about the quality of the extracted information with langextract, how could it be improved based on the options the documentation gives that we didn't try?
#
# **`Github repository for reference:`** [langextract](https://github.com/google/langextract)

# %%
# Reference Link: https://www.scholastic.com/content/dam/teachers/lesson-plans/migrated-files-in-body/sample_movie_reviews.pdf
pdf_path = "/content/drive/MyDrive/sample_movie_reviews.pdf"

formatted_text = ""

try:
    doc = pymupdf.open(pdf_path)
    # In case the PDF documents have more than one page, in this example it only has one
    for i, page in enumerate(doc):
        text = page.get_text("text")
        # Format follows the prompt's requirement: **Page X** """document's text"""
        formatted_text += f'**Page {i + 1}**\n'
        formatted_text += f'"""\n{text.strip()}\n"""\n\n'
    doc.close()
    print(f"✓ Extracted text from '{pdf_path}'")
except Exception as e:
    print(f"Could not read PDF: {e}")
    formatted_text = "Error: Could not process PDF file."
# Out:
# ✓ Extracted text from '/content/drive/MyDrive/sample_movie_reviews.pdf'

# %%
print(formatted_text)
# Out:
# **Page 1**
# """
# Home : Movies
# •
#
#
#
#
# Abigail Breslin in a scene from "Kit Kittredge: An American Girl" from HBO Films.
# Related Links
# •
# Trailer and movie times
# •
# MomsMiami.com | Share your American Girl's photo, win a Kit Kittredge doll or other prizes
# Kit Kittredge: An American Girl (G) ***
# By Rene Rodriguez, The Miami Herald
# Walking in to see Kit Kittredge: An American Girl, I was unaware the movie was spun off from a popular
# line of toy dolls -- more than 14 million of them have been sold. Nor did I know about the anticipation and
# excitement many little girls have for the movie, which is the fourth in the series (the previous three,
# made for TV, are available on DVD).
# I still have no opinion on the toys, but I can definitely vouch for the film living up to expectations. Shot
# with the burnished, luxurious cinematography of a big-budget movie, and cast with actors who never
# treat the material as if it were beneath them, Kit Kittredge: An American Girl is a thoroughly satisfying
# and engaging children's picture that never forgets those kids probably didn't get to the theater by
# themselves.
# Movie Reviews
# These examples were found on www.rottentomatoes.com.  What I like
# about this site is that it compiles many newspaper reviews onto one page.
# Visitors can then make additional comments (reviewing the reviewers).
# Here are a few movies that are geared towards kids…
# """
#
# **Page 2**
# """
# Director Patricia Rozema and screenwriter Ann Peacock avoid condescending to their target audience --
# or, for that matter, to their adult guardians -- by treating their child protagonists with care and respect.
# It helps, too, that they have the amazing Abigail Breslin (Little Miss Sunshine) in the lead role of 9-year-
# old Kit, a bright and winsome girl in Depression-era Cincinnati who aspires to be a reporter for the
# Cincinnati Register.
# Kit is constantly submitting to the paper her stories, such as a piece on the World's Fair, without much
# luck. But as the Depression starts to affect the lives of her closest friends -- and then, inevitably, her own
# family -- Kit's priorities change. Her father (Chris O'Donnell) goes to Chicago to find work and promises to
# return, but doesn't. Her mother (Julia Ormond), in a desperate attempt to save their home, starts taking
# in boarders, such as a traveling librarian (Joan Cusack), a magician (Stanley Tucci) and a fallen socialite
# (Glenn Headley) awaiting word from her own husband, who has gone to New York in search of
# employment.
# The backdrop is grim, and to its credit, the movie does not sugarcoat its portrayal of how the Depression
# affected the day-to-day lives of upper middle-class Americans who lost everything in the span of a month
# and had to figure out how to push forward.
# The filmmakers allow the story to unfold entirely through the point of view of Kit, who may not fully
# understand the severity of the situation, but is also more aware and resourceful than the adults around
# her realize. Kit Kittredge: An American Girl sends its heroine and her friends on several adventures,
# including a Nancy Drew-ish one involving some stolen valuables, but it's the movie's overall tone -- the
# innocence of children, as well as their surprising resiliency -- that elevates the film into something far
# more valuable than a feature-length commercial for toys.
# Cast: Abigail Breslin, Julia Ormond, Chris O'Donnell, Joan Cusack, Madison Davenport, Zach Mills, Glenn
# Headley, Jane Krakowski, Stanley Tucci, Wallace Shawn
# Director: Patricia Rozema
# Screenwriter: Ann Peacock. Based on the books by Valerie Tripp
# Producers: Elaine Goldsmith-Thomas, Lisa Gillan, Ellen L. Brothers
# A Picturehouse release. Running time: 100 minutes. No offensive material. Playing at area theaters.
# """
#
# **Page 3**
# """
# 'Kung Fu Panda' falls flat
#
#  Using his noodle: Panda Po (voice of Jack Black) begins his study under Master Shifu (Dustin Hoffman)
# By Claudia Puig, USA TODAY
# Though occasionally visually inventive, Kung Fu Panda is a disappointment when it comes to matters of
# simple black and white: the script.
# Everything that happens in this dull tale of Po, a paunchy panda who becomes a zealous kung fu fighter, is
# telegraphed well in advance.
# MORE: Jack Black tries his hands at kung fu
# PHOTOS: Check out Black's kung fu grip
# That might not have been a problem had the storytelling been more amusing.
# The story centers on the enthusiastic, if clumsy Po (Jack Black), a rabid armchair kung fu fan. Po's day job is
# to work in his family's noodle shop. When he's accidentally chosen as the kung fu master who will fulfill an
# ancient prophecy, he must rise to the occasion.
# Despite the panda being voiced by Black, the humorous moments are few. If you're going to cast someone
# as singularly quirky as Black, then take advantage of his eccentric persona. The role is so straightforward, it
# could have been played by anyone.
# And the supporting characters—a tiger voiced by Angelina Jolie, a crane played by David Cross, Lucy Liu as
# a viper and Jackie Chan as an agile monkey — are so lacking personality that you wonder why the
# filmmakers bothered to get such a cross section of talent.
# Sure, the message to believe in yourself is a valuable, if often-heard, one for young audiences. But it could
# have played out in a more creative way.
# Perhaps the most interesting character is Master Shifu, charmingly voiced by Dustin Hoffman. He whips Po
# into shape and reveals his own character.
# One sequence on a swinging wooden bridge is a visual treat, especially when seen in IMAX. But the film's
# climax doesn't show the fate of the bad guy. This lack of clarity might have more to do with plans for a
# sequel than bad storytelling.
# Perhaps children will be taken by Po's huggable appearance, but anyone older than 9 is likely to be bored.
# """
#
# **Page 4**
# """
# Movie Reviews
# by Bob Mondello
#
# 'Wall-E,' Speaking Volumes with Stillness and Stars
# Listen Now [4 min 37 sec] add to playlist
#
#
# Enlarge
#
# Evolutionary thinking: Wall-E may have started out as a glorified trash compactor, but he's learned how to look to the sky. Pixar
# Wall-E
# •
# Director: Andrew Stanton
# •
# Genre: Sci-Fi
# •
# Running Time: 97 minutes
# Rated G: Big-hearted and full of wonder, but too smart to be saccharine.
# “The first hour of Wall-E is a crazily inventive, deliriously engaging and almost wordless silent comedy of the sort that
# Charlie Chaplin and Buster Keaton used to make.”
#
# All Things Considered, June 27, 2008 · The camera descends, at the start of Wall-E, from
# outer space to a landscape that looks eerily familiar — and sort of not. The sun filters
# down through a brownish haze. What seem at first like skyscrapers turn out to be neatly
# stacked mountains of trash. Stillness is everywhere, broken only by the unlikely sound of
# a song from Hello, Dolly! — and a solitary figure zipping around a junk-strewn
# cityscape.
# Apparently, humans never changed course on pollution and consumerism, and sometime
# in the 22nd century they were forced to leave a planet they had turned into a giant
# garbage dump. But they left without turning off a robot they'd left behind. He's basically
# a trash compactor on treads — a Waste Allocation Load-Lifter: Earth Class, or WALL-E
# — who has, over the course of 700 years, developed a personality.
# """
#
# **Page 5**
# """
# He tries to puzzle out what mankind's detritus was for (a Rubik's cube, a spork, a fire
# extinguisher), and he saves a few items — an alarmingly fresh 700-year-old Twinkie,
# say, for his pet cockroach.
# But most of the trash he compacts and stacks, in a routine that is interrupted only when he
# falls head-over-treads for a sleek robot from the stars: EVE (for Extra-terrestrial
# Vegetation Evaluator), whom he watches from afar so he won't be incinerated.
# Eve has an itchy trigger-finger, it turns out.
# The first hour of Wall-E is a crazily inventive, deliriously engaging and almost wordless
# silent comedy of the sort that Charlie Chaplin and Buster Keaton used to make. Things
# turn more conventional in the last half hour, when pudgy, machine-dependent humans
# make an appearance, but the glow of that first part will carry you through.
# That and the majesty of the filmmaking: Wall-E's world, in all its epic decay, looks real.
# You can almost taste the dust. And it's emotionally real too — enough so that a
# cautionary tale about the environment, and about big corporations that don't take care of
# it, and about getting so caught up in our gadgetry that we forget to look at the stars all
# take a back seat to romance.
# So do some specifically cinematic subtexts. Director Andrew Stanton and his animators
# have slipped in nods not just to Hello, Dolly!, but to Star Wars and Blade Runner, An
# Inconvenient Truth and the comedies of Chaplin and Jacques Tati. More than just a nod
# to Chaplin, actually: Wall-E, with his workaholic scruffiness and his yearning for
# someone to hold hands with, might as well be Chaplin's Little Tramp.
# There's actually a nice parallel between this largely silent film and Chaplin's first sound
# film, Modern Times. In that one, the silent clown used the soundtrack mostly for music
# and effects, not for speech, just as Pixar does here. Chaplin only let you hear a human
# voice a couple of times, and only on some sort of mechanical contraption — say a closed-
# circuit TV screen — to emphasize its artificiality. It was his way of saying to the sound
# world, "OK, everybody's doing this talking thing now, but look how much more
# expressive our silent world is."
# For the first time in a Pixar movie, Wall-E's filmmakers give a nod to the world of actual
# actors and cameras — and make them artificial in the same way: by only letting you see
# them on video screens, where they look flat and washed-out compared to the digital
# world around them.
# But there's one difference. Chaplin knew he had lost the battle: Silence was finished;
# sound had won. In today's Hollywood, digital is what's taking over — in special effects,
# in green-screen work, in animation. And Pixar's animators, bless them, are at the
# """
#
# **Page 6**
# """
# forefront, insisting that imagery created on computers doesn't have to be soulless. Wall-
# E's images are filled with emotion, just as silent film's images were — even though its
# characters look like they're made of metal and plastic, and can't say a word.
# Wall-E is being sold as a futuristic fantasy, of course. But I have to say I'm just as
# gratified by their look back 70 years to silent movies as I am by their look forward 700
# years to a silent planet.
# """

# %%
import os
import langextract as lx

html_content = grounded_info_extraction(formatted_text, prompt, examples, "review_extraction_example")
# Out:
# WARNING:google_genai._api_client:Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Extracted 48 entities:
#
# • opinion_statement: 'the film living up to expectations'
#   - subject: The film
#   - sentiment: Positive
#   - key_phrase: living up to expectations
# • opinion_statement: 'Shot with the burnished, luxurious cinematography of a big-budget movie'
#   - subject: The cinematography
#   - sentiment: Positive
#   - key_phrase: burnished, luxurious
# • opinion_statement: 'cast with actors who never treat the material as if it were beneath them'
#   - subject: The actors
#   - sentiment: Positive
#   - key_phrase: never treat the material as if it were beneath them
# • opinion_statement: 'a thoroughly satisfying and engaging children's picture'
#   - subject: The children's picture
#   - sentiment: Positive
#   - key_phrase: thoroughly satisfying and engaging
# • audience_impact: 'never forgets those kids probably didn't get to the theater by themselves'
#   - emotion_evoked: ['consideration', 'empathy']
#   - causal_element: The film's understanding of its audience
#   - target_audience: children and their guardians
# • opinion_statement: 'avoid condescending to their target audience'
#   - subject: Director Patricia Rozema and screenwriter Ann Peacock
#   - sentiment: Positive
#   - key_phrase: avoid condescending
# • opinion_statement: 'treating their child protagonists with care and respect'
#   - subject: Director Patricia Rozema and screenwriter Ann Peacock
#   - sentiment: Positive
#   - key_phrase: care and respect
# • opinion_statement: 'the amazing Abigail Breslin'
#   - subject: Abigail Breslin
#   - sentiment: Positive
#   - key_phrase: amazing
# • opinion_statement: 'a bright and winsome girl'
#   - subject: Kit
#   - sentiment: Positive
#   - key_phrase: bright and winsome
# • opinion_statement: 'falls flat'
#   - subject: Kung Fu Panda
#   - sentiment: Negative
#   - key_phrase: falls flat
# • opinion_statement: 'occasionally visually inventive'
#   - subject: The film
#   - sentiment: Positive
#   - key_phrase: visually inventive
# • opinion_statement: 'a disappointment when it comes to matters of simple black and white: the script'
#   - subject: The script
#   - sentiment: Negative
#   - key_phrase: a disappointment
# • opinion_statement: 'dull tale'
#   - subject: The tale of Po
#   - sentiment: Negative
#   - key_phrase: dull
# • opinion_statement: 'telegraphed well in advance'
#   - subject: Everything that happens
#   - sentiment: Negative
#   - key_phrase: telegraphed well in advance
# • opinion_statement: 'storytelling been more amusing'
#   - subject: The storytelling
#   - sentiment: Negative
#   - key_phrase: more amusing
# • opinion_statement: 'humorous moments are few'
#   - subject: The humorous moments
#   - sentiment: Negative
#   - key_phrase: few
# • opinion_statement: 'The role is so straightforward, it could have been played by anyone'
#   - subject: The role
#   - sentiment: Negative
#   - key_phrase: so straightforward
# • opinion_statement: 'supporting characters... are so lacking personality'
#   - subject: The supporting characters
#   - sentiment: Negative
#   - key_phrase: lacking personality
# • opinion_statement: 'message to believe in yourself is a valuable, if often-heard, one'
#   - subject: The message
#   - sentiment: Positive
#   - key_phrase: valuable
# • opinion_statement: 'could have played out in a more creative way'
#   - subject: The message
#   - sentiment: Negative
#   - key_phrase: more creative way
# • opinion_statement: 'Perhaps the most interesting character is Master Shifu'
#   - subject: Master Shifu
#   - sentiment: Positive
#   - key_phrase: most interesting
# • opinion_statement: 'charming voiced'
#   - subject: Master Shifu
#   - sentiment: Positive
#   - key_phrase: charmingly voiced
# • opinion_statement: 'One sequence on a swinging wooden bridge is a visual treat'
#   - subject: One sequence on a swinging wooden bridge
#   - sentiment: Positive
#   - key_phrase: visual treat
# • opinion_statement: 'the film's climax doesn't show the fate of the bad guy'
#   - subject: The film's climax
#   - sentiment: Negative
#   - key_phrase: doesn't show the fate of the bad guy
# • opinion_statement: 'This lack of clarity'
#   - subject: The film's climax
#   - sentiment: Negative
#   - key_phrase: lack of clarity
# • audience_impact: 'Perhaps children will be taken by Po's huggable appearance'
#   - emotion_evoked: ['taken', 'charmed']
#   - causal_element: Po's huggable appearance
#   - target_audience: children
# • audience_impact: 'anyone older than 9 is likely to be bored'
#   - emotion_evoked: ['bored']
#   - causal_element: The film
#   - target_audience: anyone older than 9
# • opinion_statement: 'Big-hearted and full of wonder, but too smart to be saccharine.'
#   - subject: Wall-E
#   - sentiment: Positive
#   - key_phrase: Big-hearted and full of wonder, but too smart to be saccharine
# • opinion_statement: 'a crazily inventive, deliriously engaging and almost wordless silent comedy'
#   - subject: The first hour of Wall-E
#   - sentiment: Positive
#   - key_phrase: crazily inventive, deliriously engaging and almost wordless silent comedy
# • audience_impact: 'deliriously engaging'
#   - emotion_evoked: ['engaged']
#   - causal_element: The first hour of Wall-E
#   - target_audience: the audience
# • opinion_statement: 'a crazily inventive, deliriously engaging and almost wordless silent comedy'
#   - subject: The first hour of Wall-E
#   - sentiment: Positive
#   - key_phrase: crazily inventive, deliriously engaging and almost wordless silent comedy
# • opinion_statement: 'Things turn more conventional in the last half hour'
#   - subject: The last half hour
#   - sentiment: Neutral
#   - key_phrase: more conventional
# • audience_impact: 'the glow of that first part will carry you through'
#   - emotion_evoked: ['satisfied', 'content']
#   - causal_element: The first hour of Wall-E
#   - target_audience: the audience
# • opinion_statement: 'the majesty of the filmmaking'
#   - subject: The filmmaking
#   - sentiment: Positive
#   - key_phrase: majesty
# • opinion_statement: 'Wall-E's world, in all its epic decay, looks real'
#   - subject: Wall-E's world
#   - sentiment: Positive
#   - key_phrase: looks real
# • audience_impact: 'You can almost taste the dust'
#   - emotion_evoked: ['immersed']
#   - causal_element: Wall-E's world
#   - target_audience: the audience
# • opinion_statement: 'it's emotionally real too'
#   - subject: Wall-E's world
#   - sentiment: Positive
#   - key_phrase: emotionally real
# • opinion_statement: 'a cautionary tale about the environment, and about big corporations that don't take care of it, and about getting so caught up in our gadgetry that we forget to look at the stars'
#   - subject: The themes
#   - sentiment: Neutral
#   - key_phrase: cautionary tale
# • opinion_statement: 'Director Andrew Stanton and his animators have slipped in nods not just to Hello, Dolly!, but to Star Wars and Blade Runner, An Inconvenient Truth and the comedies of Chaplin and Jacques Tati'
#   - subject: Director Andrew Stanton and his animators
#   - sentiment: Positive
#   - key_phrase: slipped in nods
# • opinion_statement: 'Wall-E, with his workaholic scruffiness and his yearning for someone to hold hands with, might as well be Chaplin's Little Tramp'
#   - subject: Wall-E
#   - sentiment: Positive
#   - key_phrase: might as well be Chaplin's Little Tramp
# • opinion_statement: 'a nice parallel between this largely silent film and Chaplin's first sound film, Modern Times'
#   - subject: The film
#   - sentiment: Positive
#   - key_phrase: nice parallel
# • opinion_statement: 'the silent clown used the soundtrack mostly for music and effects, not for speech, just as Pixar does here'
#   - subject: The soundtrack
#   - sentiment: Neutral
#   - key_phrase: used mostly for music and effects, not for speech
# • opinion_statement: 'Chaplin only let you hear a human voice a couple of times, and only on some sort of mechanical contraption — say a closed-circuit TV screen — to emphasize its artificiality'
#   - subject: Chaplin's use of human voice
#   - sentiment: Neutral
#   - key_phrase: emphasize its artificiality
# • opinion_statement: 'look how much more expressive our silent world is'
#   - subject: The silent world
#   - sentiment: Positive
#   - key_phrase: more expressive
# • opinion_statement: 'Wall-E's filmmakers give a nod to the world of actual actors and cameras — and make them artificial in the same way: by only letting you see them on video screens, where they look flat and washed-out compared to the digital world around them'
#   - subject: Wall-E's filmmakers' nod to actual actors and cameras
#   - sentiment: Negative
#   - key_phrase: make them artificial... where they look flat and washed-out
# • opinion_statement: 'imagery created on computers doesn't have to be soulless'
#   - subject: Imagery created on computers
#   - sentiment: Positive
#   - key_phrase: doesn't have to be soulless
# • opinion_statement: 'Wall-E's images are filled with emotion'
#   - subject: Wall-E's images
#   - sentiment: Positive
#   - key_phrase: filled with emotion
# • opinion_statement: 'I'm just as gratified by their look back 70 years to silent movies as I am by their look forward 700 years to a silent planet'
#   - subject: The film's blend of past and future themes
#   - sentiment: Positive
#   - key_phrase: gratified by their look back...as I am by their look forward
# LangExtract: Saving to review_extraction_example.jsonl: 1 docs [00:00, 167.96 docs/s]
# ✓ Saved 1 documents to review_extraction_example.jsonl
# LangExtract: Loading review_extraction_example.jsonl: 100%|██████████| 30.2k/30.2k [00:00<00:00, 27.0MB/s]
# ✓ Loaded 1 documents from review_extraction_example.jsonl
# ✓ Visualization saved to ./DM2025-Lab2-Exercise/results/info_extractions/review_extraction_example_vis.html

# %%
html_content
# Out:
# <style>
# .lx-highlight { position: relative; border-radius:3px; padding:1px 2px;}
# .lx-highlight .lx-tooltip {
#   visibility: hidden;
#   opacity: 0;
#   transition: opacity 0.2s ease-in-out;
#   background: #333;
#   color: #fff;
#   text-align: left;
#   border-radius: 4px;
#   padding: 6px 8px;
#   position: absolute;
#   z-index: 1000;
#   bottom: 125%;
#   left: 50%;
#   transform: translateX(-50%);
#   font-size: 12px;
#   max-width: 240px;
#   white-space: normal;
#   box-shadow: 0 2px 6px rgba(0,0,0,0.3);
# }
# .lx-highlight:hover .lx-tooltip { visibility: visible; opacity:1; }
# .lx-animated-wrapper { max-width: 100%; font-family: Arial, sans-serif; }
# .lx-controls {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 8px;
#   padding: 12px; margin-bottom: 16px;
# }
# .lx-button-row {
#   display: flex; justify-content: center; gap: 8px; margin-bottom: 12px;
# }
# .lx-control-btn {
#   background: #4285f4; color: white; border: none; border-radius: 4px;
#   padding: 8px 16px; cursor: pointer; font-size: 13px; font-weight: 500;
#   transition: background-color 0.2s;
# }
# .lx-control-btn:hover { background: #3367d6; }
# .lx-progress-container {
#   margin-bottom: 8px;
# }
# .lx-progress-slider {
#   width: 100%; margin: 0; appearance: none; height: 6px;
#   background: #ddd; border-radius: 3px; outline: none;
# }
# .lx-progress-slider::-webkit-slider-thumb {
#   appearance: none; width: 18px; height: 18px; background: #4285f4;
#   border-radius: 50%; cursor: pointer;
# }
# .lx-progress-slider::-moz-range-thumb {
#   width: 18px; height: 18px; background: #4285f4; border-radius: 50%;
#   cursor: pointer; border: none;
# }
# .lx-status-text {
#   text-align: center; font-size: 12px; color: #666; margin-top: 4px;
# }
# .lx-text-window {
#   font-family: monospace; white-space: pre-wrap; border: 1px solid #90caf9;
#   padding: 12px; max-height: 260px; overflow-y: auto; margin-bottom: 12px;
#   line-height: 1.6;
# }
# .lx-attributes-panel {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 6px;
#   padding: 8px 10px; margin-top: 8px; font-size: 13px;
# }
# .lx-current-highlight {
#   border-bottom: 4px solid #ff4444;
#   font-weight: bold;
#   animation: lx-pulse 1s ease-in-out;
# }
# @keyframes lx-pulse {
#   0% { text-decoration-color: #ff4444; }
#   50% { text-decoration-color: #ff0000; }
#   100% { text-decoration-color: #ff4444; }
# }
# .lx-legend {
#   font-size: 12px; margin-bottom: 8px;
#   padding-bottom: 8px; border-bottom: 1px solid #e0e0e0;
# }
# .lx-label {
#   display: inline-block;
#   padding: 2px 4px;
#   border-radius: 3px;
#   margin-right: 4px;
#   color: #000;
# }
# .lx-attr-key {
#   font-weight: 600;
#   color: #1565c0;
#   letter-spacing: 0.3px;
# }
# .lx-attr-value {
#   font-weight: 400;
#   opacity: 0.85;
#   letter-spacing: 0.2px;
# }
#
# /* Add optimizations with larger fonts and better readability for GIFs */
# .lx-gif-optimized .lx-text-window { font-size: 16px; line-height: 1.8; }
# .lx-gif-optimized .lx-attributes-panel { font-size: 15px; }
# .lx-gif-optimized .lx-current-highlight { text-decoration-thickness: 4px; }
# </style>
#     <div class="lx-animated-wrapper lx-gif-optimized">
#       <div class="lx-attributes-panel">
#         <div class="lx-legend">Highlights Legend: <span class="lx-label" style="background-color:#D2E3FC;">audience_impact</span> <span class="lx-label" style="background-color:#C8E6C9;">opinion_statement</span></div>
#         <div id="attributesContainer"></div>
#       </div>
#       <div class="lx-text-window" id="textWindow">
#         **Page 1**
# &quot;&quot;&quot;
# Home : Movies
# •
#
#
#
#
# Abigail Breslin in a scene from &quot;Kit Kittredge: An American Girl&quot; from HBO Films.
# Related Links
# •
# Trailer and movie times
# •
# MomsMiami.com | Share your American Girl&#x27;s photo, win a Kit Kittredge doll or other prizes
# Kit Kittredge: An American Girl (G) ***
# By Rene Rodriguez, The Miami Herald
# Walking in to see Kit Kittredge: An American Girl, I was unaware the movie was spun off from a popular
# line of toy dolls -- more than 14 million of them have been sold. Nor did I know about the anticipation and
# excitement many little girls have for the movie, which is the fourth in the series (the previous three,
# made for TV, are available on DVD).
# I still have no opinion on the toys, but I can definitely vouch for <span class="lx-highlight lx-current-highlight" data-idx="0" style="background-color:#C8E6C9;">the film living up to expectations</span>. <span class="lx-highlight" data-idx="1" style="background-color:#C8E6C9;">Shot
# with the burnished, luxurious cinematography of a big-budget movie</span>, and <span class="lx-highlight" data-idx="2" style="background-color:#C8E6C9;">cast with actors who never
# treat the material as if it were beneath them</span>, Kit Kittredge: An American Girl is <span class="lx-highlight" data-idx="3" style="background-color:#C8E6C9;">a thoroughly satisfying
# and engaging children&#x27;s picture</span> that <span class="lx-highlight" data-idx="4" style="background-color:#D2E3FC;">never forgets those kids probably didn&#x27;t get to the theater by
# themselves</span>.
# Movie Reviews
# These examples were found on www.rottentomatoes.com.  What I like
# about this site is that it compiles many newspaper reviews onto one page.
# Visitors can then make additional comments (reviewing the reviewers).
# Here are a few movies that are geared towards kids…
# &quot;&quot;&quot;
#
# **Page 2**
# &quot;&quot;&quot;
# Director Patricia Rozema and screenwriter Ann Peacock <span class="lx-highlight" data-idx="5" style="background-color:#C8E6C9;">avoid condescending to their target audience</span> --
# or, for that matter, to their adult guardians -- by <span class="lx-highlight" data-idx="6" style="background-color:#C8E6C9;">treating their child protagonists with care and respect</span>.
# It helps, too, that they have <span class="lx-highlight" data-idx="7" style="background-color:#C8E6C9;">the amazing Abigail Breslin</span> (Little Miss Sunshine) in the lead role of 9-year-
# old Kit, <span class="lx-highlight" data-idx="8" style="background-color:#C8E6C9;">a bright and winsome girl</span> in Depression-era Cincinnati who aspires to be a reporter for the
# Cincinnati Register.
# Kit is constantly submitting to the paper her stories, such as a piece on the World&#x27;s Fair, without much
# luck. But as the Depression starts to affect the lives of her closest friends -- and then, inevitably, her own
# family -- Kit&#x27;s priorities change. Her father (Chris O&#x27;Donnell) goes to Chicago to find work and promises to
# return, but doesn&#x27;t. Her mother (Julia Ormond), in a desperate attempt to save their home, starts taking
# in boarders, such as a traveling librarian (Joan Cusack), a magician (Stanley Tucci) and a fallen socialite
# (Glenn Headley) awaiting word from her own husband, who has gone to New York in search of
# employment.
# The backdrop is grim, and to its credit, the movie does not sugarcoat its portrayal of how the Depression
# affected the day-to-day lives of upper middle-class Americans who lost everything in the span of a month
# and had to figure out how to push forward.
# The filmmakers allow the story to unfold entirely through the point of view of Kit, who may not fully
# understand the severity of the situation, but is also more aware and resourceful than the adults around
# her realize. Kit Kittredge: An American Girl sends its heroine and her friends on several adventures,
# including a Nancy Drew-ish one involving some stolen valuables, but it&#x27;s the movie&#x27;s overall tone -- the
# innocence of children, as well as their surprising resiliency -- that elevates the film into something far
# more valuable than a feature-length commercial for toys.
# Cast: Abigail Breslin, Julia Ormond, Chris O&#x27;Donnell, Joan Cusack, Madison Davenport, Zach Mills, Glenn
# Headley, Jane Krakowski, Stanley Tucci, Wallace Shawn
# Director: Patricia Rozema
# Screenwriter: Ann Peacock. Based on the books by Valerie Tripp
# Producers: Elaine Goldsmith-Thomas, Lisa Gillan, Ellen L. Brothers
# A Picturehouse release. Running time: 100 minutes. No offensive material. Playi

# %%
# Overall, this model performed quite well. It extracted almost the entire content of the review and produced an accurate sentimental analysis over the main opinion spans. However, there are still several adjustments that could further improve extraction quality: based on the Langextract and Gemini documentation, using a stronger model variant (e.g., gemini-2.5-pro), increasing extraction_passes to improve recall on longer reviews, reducing max_char_buffer to obtain finer-grained chunks, and lowering the temperature to stabilize sentimental analysis would be more consistent and comprehensive.

# %% [markdown]
# ---
# ### **2.4 Generating LLM Embeddings:**
#
# LLM embeddings are dense numerical vectors that represent the semantic meaning of text. Generated by Large Language Models, they map words, phrases, or documents into a high-dimensional space where similar concepts are positioned closely together.
#
# Their key advantages are:
#
# *   **Contextual Understanding:** Unlike older methods, LLM embeddings are contextual. The vector for a word like **"bank"** will be different depending on whether it's used in the context of a "river bank" or a "money bank," providing a more nuanced representation of language.
#
# *   **Versatility from Pre-training:** They are pre-trained on vast amounts of text data. This allows them to generalize effectively across various tasks, such as classification, clustering, and similarity detection. They do not require extensive retraining.
#
# <span style="color:green">For the exercise in this section there is no need to re-run the cells, you can use the data that has been saved previously to the corresponding directory.</span>
#
# **Now let's generate some embeddings with Gemini for a sample of our dataset:**

# %%
from google import genai
import pandas as pd
import time
from google.api_core import exceptions

# Let's define our function to get the embeddings with Gemini
def get_gemini_embedding(text: str, model: str="gemini-embedding-001"):
    try:
        result = client.models.embed_content(model=model, contents=[text])
        # 100 requests per minute limit -> 60s / 100 = 0.6s per request
        # buffer time to avoid rate limits
        time.sleep(0.6)
        return result.embeddings
    except exceptions.ResourceExhausted as e:
        print(f"Rate limit exceeded. Waiting to retry... Error: {e}")
        time.sleep(5) # Wait for 5 seconds before the next attempt
        return get_gemini_embedding(text, model) # Retry the request
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# %%
total_extractions = 200
train_ratio = 0.8
test_ratio = 0.2

n_train_to_sample = int(total_extractions * train_ratio)
n_test_to_sample = int(total_extractions * test_ratio)
# We use the text column
column_name = 'text'

# This function is to get a stratified sample from our data, meaning to have the same distribution of labels as in the full dataset
def stratified_sample(df: pd.DataFrame, n_samples: int, stratify_col: str = 'emotion') -> pd.DataFrame:
    if n_samples >= len(df):
        return df.copy() # Return a copy if requested sample is larger or equal
    sampled_df = df.groupby(stratify_col, group_keys=False).apply(
        lambda x: x.sample(n=max(0, int(round(len(x) / len(df) * n_samples))))
    )

    # Adjust for rounding errors to get the exact number of samples
    current_samples = len(sampled_df)
    if current_samples < n_samples:
        remaining_indices = df.index.difference(sampled_df.index)
        additional_samples = df.loc[remaining_indices].sample(n=n_samples - current_samples, random_state=42)
        sampled_df = pd.concat([sampled_df, additional_samples])
    elif current_samples > n_samples:
        sampled_df = sampled_df.sample(n=n_samples, random_state=42)
    return sampled_df

print(f"Sampling {n_train_to_sample} rows from the training set...")
train_df_new = stratified_sample(train_df, n_train_to_sample, 'emotion')

print(f"Sampling {n_test_to_sample} rows from the test set...")
test_df_new = stratified_sample(test_df, n_test_to_sample, 'emotion')
# Out:
# Sampling 160 rows from the training set...
# Sampling 40 rows from the test set...
# /tmp/ipython-input-2000596105.py:14: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_df = df.groupby(stratify_col, group_keys=False).apply(
# /tmp/ipython-input-2000596105.py:14: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_df = df.groupby(stratify_col, group_keys=False).apply(

# %%
train_df_new["emotion"].value_counts()
# Out:
# emotion
# fear       51
# anger      38
# joy        36
# sadness    35
# Name: count, dtype: int64

# %%
test_df_new["emotion"].value_counts()
# Out:
# emotion
# fear       13
# anger      10
# joy         9
# sadness     8
# Name: count, dtype: int64

# %%
# Apply the function to the specified column and store the result in a new column 'embeddings'
print("\nGenerating embeddings for the new training set...")
train_df_new['embeddings'] = train_df_new[column_name].apply(get_gemini_embedding)
# Out:
# Generating embeddings for the new training set...

# %%
print("\nGenerating embeddings for the new test set...")
test_df_new['embeddings'] = test_df_new[column_name].apply(get_gemini_embedding)
# Out:
# Generating embeddings for the new test set...

# %%
from google.genai import types

# After getting the embeddings we need to convert the Gemini type ContentDict of the embeddings into a simple list with them
train_df_new['embeddings_values'] = train_df_new["embeddings"].apply(lambda row: list(types.ContentDict(row[0]).values())[0])
test_df_new['embeddings_values'] = test_df_new["embeddings"].apply(lambda row: list(types.ContentDict(row[0]).values())[0])

# %%
train_df_new #We can see the new column with the embeddings
# Out:
#          id                                               text  emotion  \
# 139   10139  @ManUtd you have had from me over the years is...    anger
# 635   10635  When anger rises, think of the consequences. #...    anger
# 567   10567  Projection is perception. See it in someone el...    anger
# 189   10189  All hell is breaking loose in Charlotte. #Char...    anger
# 601   10601  straight people are canoodling on the quad and...    anger
# ...     ...                                                ...      ...
# 3028  40201  Isn't the whole 'it's been hijacked' argument ...  sadness
# 3377  40550  the grave of a beat, a bravehearted cave lover...  sadness
# 3531  40704  Hello fellow #horror #creepy #dark #stange #st...  sadness
# 3435  40608  Somehow 90% of the sausage in this pasta I mad...  sadness
# 3560  40733  Be joyful in hope, patient in affliction, fait...  sadness
#
#       intensity                                         embeddings  \
# 139       0.667  [values=[-0.012735673, -0.0029814306, -0.01388...
# 635       0.433  [values=[-0.0007034148, -0.00026035903, 0.0020...
# 567       0.417  [values=[0.0006323633, -0.010247843, 0.0042307...
# 189       0.625  [values=[-0.025623817, 0.021766266, -0.0136092...
# 601       0.417  [values=[-0.027476152, 0.0064917235, -0.023904...
# ...         ...                                                ...
# 3028      0.636  [values=[-0.0014998951, -0.00993281, -0.018238...
# 3377      0.375  [values=[0.01149004, 0.004404286, 0.005442719,...
# 3531      0.263  [values=[-0.013339969, 0.0027367186, 0.0053192...
# 3435      0.333  [values=[0.025451547, 0.018981425, 0.001123852...
# 3560      0.216  [values=[-0.012677698, 0.0039568115, -0.013947...
#
#                                       embeddings_values
# 139   [-0.012735673, -0.0029814306, -0.013887807, -0...
# 635   [-0.0007034148, -0.00026035903, 0.0020191805, ...
# 567   [0.0006323633, -0.010247843, 0.0042307465, -0....
# 189   [-0.025623817, 0.021766266, -0.013609226, -0.0...
# 601   [-0.027476152, 0.0064917235, -0.023904316, -0....
# ...                                                 ...
# 3028  [-0.0014998951, -0.00993281, -0.018238502, -0....
# 3377  [0.01149004, 0.004404286, 0.005442719, -0.0928...
# 3531  [-0.013339969, 0.0027367186, 0.0053192284, -0....
# 3435  [0.025451547, 0.018981425, 0.0011238529, -0.07...
# 3560  [-0.012677698, 0.0039568115, -0.013947626, -0....
#
# [160 rows x 6 columns]

# %%
test_df_new #We can see the new column with the embeddings
# Out:
#         id                                               text  emotion  \
# 222  30851  Heather that was #hilarious! @MsHeatherBates @...      joy
# 129  21192  And I cried in front of my guy last night. And...     fear
# 0    10857  @ZubairSabirPTI  pls dont insult the word 'Molna'    anger
# 197  30826  @tomderivan73 😁...I'll just people watch and e...      joy
# 73   10930  @HomeSwapperteam  Spent months arranging swap ...    anger
# 282  40795  watching this uni reveal is so depressing i mi...  sadness
# 171  21234  Trying to book holiday flights on @britishairw...     fear
# 281  40794  @ccrago It was dreadful, even after he met the...  sadness
# 248  30877  @airtelindia have some issues with my broadban...      joy
# 40   10897                 Might just leave and aggravate bae    anger
# 206  30835  @Gronnhair @buryprofs @DittoBistro it was inde...      joy
# 124  21187  ⊰ @FrameOfAnAngel ⊱ \n\n+ Of them. I'm here fo...     fear
# 167  21230  It really is amazing the money they give to so...     fear
# 33   10890           All Brian does is sleep and aggravate me    anger
# 143  21206  Dunno y am going to the Yorkshire scare ground...     fear
# 324  40837  @Virgin_TrainsEC I feel for the conductor toni...  sadness
# 144  21207  @LethalWeaponFOX This show SUCKS! #lame #awful...     fear
# 293  40806       Season 3 and Charlie is still a prick! #lost  sadness
# 322  40835  @Eeevah14 don't I know it, try not to fret my ...  sadness
# 14   10871  Sorry guys I have absolutely no idea what time...    anger
# 242  30871             @hesham786 that's the spirit #optimism      joy
# 12   10869  Me being on my dean really saving a lot of ppl...    anger
# 126  21189  @SAHARTHERAPPER I unfollowed without hesitatio...     fear
# 18   10875             @TrussElise Obama must be fuming.. lol    anger
# 199  30828  I love my family so much #lucky #grateful #sma...      joy
# 136  21199  Ever been really lonely and your phone keeps b...     fear
# 67   10924  Anger, resentment, and hatred are the destroye...    anger
# 272  30901    A hearty Jonza! to all my friends and follower.      joy
# 346  40859  @KeithOlbermann depressing how despicable Trum...  sadness
# 75   10932                            @DJ_JeanFranko growl!!!    anger
# 340  40853  @xOffWithMyHeadx They've officially said all t...  sadness
# 245  30874   @harrietemmett great minds think alike. #rejoice      joy
# 344  40857  If you #invest in my new #film I will stop ask...  sadness
# 183  21246  @AaliyahLove69 I would be intimidated but I wo...     fear
# 137  21200  My Modern Proverb: 'Don't let anyone intimidat...     fear
# 135  21198  #Awareness seek #shelter .#Letgo Old #habit of...     fear
# 117  21180  The 2nd step to beating #anxiety or #depressio...     fear
# 31   10888                            The rage has died down.    anger
# 122  21185  On @Varneyco/@FoxBusiness to talk latest on #C...     fear
# 261  30890  A lifetime of laughter at the expense of the d...      joy
#
#      intensity                                         embeddings  \
# 222      0.812  [values=[-0.023940003, 0.0017229738, 0.0072910...
# 129      0.680  [values=[-0.006811888, -0.007458425, -0.008265...
# 0        0.479  [values=[0.009774932, 0.0055678063, -0.0006229...
# 197      0.438  [values=[-0.0028830545, -0.019134942, -0.00139...
# 73       0.667  [values=[-0.004661313, 0.008528503, -0.0286473...
# 282      0.667  [values=[-0.01416594, -0.0020495555, 0.0126896...
# 171      0.458  [values=[-0.04059941, -0.018868277, -0.0080992...
# 281      0.542  [values=[-0.024175065, -0.016342454, -0.008305...
# 248      0.340  [values=[-0.016282463, 0.020544332, -0.0071069...
# 40       0.417  [values=[-0.010166713, 0.0014822743, -0.011168...
# 206      0.646  [values=[-0.011633852, -0.009310706, -0.011479...
# 124      0.583  [values=[-0.029143142, -0.026484871, -0.000989...
# 167      0.246  [values=[-0.04023646, -0.0033757573, -0.015112...
# 33       0.833  [values=[-0.016705524, -0.008376931, -0.018700...
# 143      0.812  [values=[-0.008968516, -0.04955138, 0.00320910...
# 324      0.667  [values=[-0.021651793, 0.0021797267, -0.001286...
# 144      0.396  [values=[-0.04764038, 0.010794757, 0.004717541...
# 293      0.375  [values=[-0.0062663667, 0.0028780843, 0.017240...
# 322      0.333  [values=[0.017147837, 0.010600609, -0.00488683...
# 14       0.202  [values=[-0.025927138, 0.0076092225, -0.028915...
# 242      0.396  [values=[0.0038663426, -0.011033859, -0.002288...
# 12       0.348  [values=[0.0064007128, -0.0034983447, -0.00495...
# 126      0.229  [values=[-0.0005891733, 0.014120081, -0.025740...
# 18       0.500  [values=[-0.0028347652, 0.04002049, -0.0105925...
# 199      0.792  [values=[-0.041261364, -0.0025729102, 0.000523...
# 136      0.740  [values=[-0.017594485, -0.02038086, -0.0274361...
# 67       0.396  [values=[0.0054825684, 0.013875896, -0.0055669...
# 272      0.704  [values=[0.0013084331, 0.007918925, -0.0007036...
# 346      0.708  [values=[0.010130299, -0.0058035105, 0.0167581...
# 75       0.500  [values=[0.015252903, 0.0042496077, 0.02459122...
# 340      0.438  [values=[0.02956792, 0.0002164427, -0.02829732...
# 245      0.519  [values=[-0.013035271, 0.0017458068, -0.017289...
# 344      0.458  [values=[-0.012564192, -0.012203087, 0.0146256...
# 183      0.417  [values=[-0.0041318764, -0.040916465, 0.015833...
# 137      0.312  [values=[-0.0033947802, 0.004203463, 0.0055387...
# 135      0.438  [values=[-0.013722948, -0.010812345, 0.0069524...
# 117      0.479  [values=[0.023471452, -0.010988598, 0.02061124...
# 31       0.438  [values=[0.009757778, -0.0028747309, -0.004763...
# 122      0.642  [values=[-0.03771063, -0.0065209107, -0.003543...
# 261      0.354  [values=[0.0102727655, 0.031475015, 0.00417681...
#
#                                      embeddings_values
# 222  [-0.023940003, 0.0017229738, 0.007291086, -0.0...
# 129  [-0.006811888, -0.007458425, -0.008265424, -0....
# 0    [0.009774932, 0.0055678063, -0.00062292145, -0...
# 197  [-0.0028830545, -0.019134942, -0.0013986382, -...
# 73   [-0.004661313, 0.008528503, -0.028647302, -0.0...
# 282  [-0.01416594, -0.0020495555, 0.012689669, -0.0...
# 171  [-0.04059941, -0.018868277, -0.008099283, -0.0...
# 281  [-0.024175065, -0.016342454, -0.008305394, -0....
# 248  [-0.016282463, 0.020544332, -0.0071069333, -0....
# 40   [-0.010166713, 0.0014822743, -0.0111685805, -0...
# 206  [-0.011633852, -0.009310706, -0.011479081, -0....
# 124  [-0.029143142, -0.026484871, -0.0009893685, -0...
# 167  [-0.04023646, -0.0033757573, -0.015112562, -0....
# 33   [-0.016705524, -0.008376931, -0.01870026, -0.0...
# 143  [-0.008968516, -0.04955138, 0.0032091022, -0.0...
# 324  [-0.021651793, 0.0021797267, -0.0012866711, -0...
# 144  [-0.04764038, 0.010794757, 0.0047175414, -0.05...
# 293  [-0.0062663667, 0.0028780843, 0.017240373, -0....
# 322  [0.017147837, 0.010600609, -0.0048868353, -0.0...
# 14   [-0.025927138, 0.0076092225, -0.028915087, -0....
# 242  [0.0038663426, -0.011033859, -0.002288114, -0....
# 12   [0.0064007128, -0.0034983447, -0.004954461, -0...
# 126  [-0.0005891733, 0.014120081, -0.025740528, -0....
# 18   [-0.0028347652, 0.04002049, -0.010592525, -0.0...
# 199  [-0.041261364, -0.0025729102, 0.00052370684, -...
# 136  [-0.017594485, -0.02038086, -0.027436184, -0.0...
# 67   [0.0054825684, 0.013875896, -0.0055669188, -0....
# 272  [0.0013084331, 0.007918925, -0.0007036131, -0....
# 346  [0.010130299, -0.0058035105, 0.016758112, -0.0...
# 75   [0.015252903, 0.0042496077, 0.024591228, -0.08...
# 340  [0.02956792, 0.0002164427, -0.02829732, -0.068...
# 245  [-0.013035271, 0.0017458068, -0.017289385, -0....
# 344  [-0.012564192, -0.012203087, 0.014625612, -0.0...
# 183  [-0.0041318764, -0.040916465, 0.015833594, -0....
# 137  [-0.0033947802, 0.004203463, 0.005538775, -0.0...
# 135  [-0.013722948, -0.010812345, 0.0069524553, -0....
# 117  [0.023471452, -0.010988598, 0.020611243, -0.04...
# 31   [0.009757778, -0.0028747309, -0.0047637797, -0...
# 122  [-0.03771063, -0.0065209107, -0.0035432605, -0...
# 261  [0.0102727655, 0.031475015, 0.0041768197, -0.0...

# %%
# save them to pickle files
train_df_new.to_pickle("./DM2025-Lab2-Exercise/data/train_df_sample_embeddings.pkl")
test_df_new.to_pickle("./DM2025-Lab2-Exercise/data/test_df_sample_embeddings.pkl")

# %%
import pandas as pd
# load the pickle files
train_df_new = pd.read_pickle("./DM2025-Lab2-Exercise/data/train_df_sample_embeddings.pkl")
test_df_new = pd.read_pickle("./DM2025-Lab2-Exercise/data/test_df_sample_embeddings.pkl")

# %%
len(train_df_new.iloc[0]["embeddings_values"]) # Gemini embedding dimension is 3072
# Out:
# 3072

# %%
import pandas as pd
import numpy as np
import umap
import plotly.express as px

# Concatenate the training and test data
combined_df = pd.concat([train_df_new, test_df_new], ignore_index=True)

# Prepare the embeddings for UMAP
# Convert the list of embeddings into a 2D numpy array
X_embeddings = np.array(combined_df['embeddings_values'].tolist())

# Apply UMAP for dimensionality reduction
reducer = umap.UMAP(n_components=2, metric='cosine', random_state=28)
embedding_2d = reducer.fit_transform(X_embeddings)

# Create a DataFrame for plotting
df_plot = pd.DataFrame(embedding_2d, columns=['UMAP1', 'UMAP2'])
df_plot['emotion'] = combined_df['emotion']
df_plot['intensity'] = combined_df['intensity']
df_plot['text'] = combined_df['text']


# Visualize the embeddings with Plotly
fig = px.scatter(
    df_plot,
    x='UMAP1',
    y='UMAP2',
    color='emotion',  # Color points by the 'emotion' column
    hover_data=['text', 'intensity'],  # Show text and intensity on hover
    title='2D UMAP Projection of Text Embeddings'
)

fig.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="be7947df-3f86-4e70-99ff-1b6f4a065df0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("be7947df-3f86-4e70-99ff-1b6f4a065df0")) {                    Plotly.newPlot(                        "be7947df-3f86-4e70-99ff-1b6f4a065df0",                        [{"customdata":[["@ManUtd you have had from me over the years is irrelevant. Its an absolute joke. #manutd #ticketing  #noloyalty #joke #notimpressed",0.667],["When anger rises, think of the consequences. #quote #wisdom #anger",0.433],["Projection is perception. See it in someone else? You also at some level have that within you. #anger #worry",0.417],["All hell is breaking loose in Charlotte. #CharlotteProtest  #looting",0.625],["straight people are canoodling on the quad and I'm ",0.417],["@kingcharles9th i Lowkey forgot you had twitter and if you don't follow me back im gonna be #offended",0.421],["Sorry to burst your bubble but it isn't that century anymore. Welcome to the 21st century.",0.354],["@ThomsonCares Sam- yes we have! Not helpful at all! We need this sorting ASAP! You keep promising stuff that doesn't happen!!!! #fuming",0.771],["@CBSBigBrother never bring back Meech and Bridgette. Crying because someone looks at you? Ugh, and Bridgette. ",0.479],["@sueblue35 @nsoz7 @immortalbulldog huh? We have a sprint coach? We're the slowest team in the comp. Talk about robbing a living. ",0.292],["If my luck the rest of Fall goes anything like today, I think I'm going to like this season. #bestdayever #magic #work ",0.375],["@TzumiXIV huff puff",0.519],["@paulbushnell25 @EE bad news if ordered online it hasn't gone through same happened to me had to re order on the phone #furious",0.844],["@RealBD_ @ReyesAverie 47 unarmed blacks killed by white cops in 2015. That many die every month in Chicago wheres the #outrage",0.646],["Why a puerto Rican with Taino hair and a black nose gotta ruffle your targeted feathers?",0.5],["Ok but I just got called a 'White Devil' on the train and I didnt know whether to laugh or be offended",0.484],["@BIGGKATZ BUT arms (focused rage) is overpowered, it will be getting nerfed. It'll still be stronger than fury though",0.468],["@ManUtd you have had from me over the years is irrelevant. Its an absolute joke. #manutd #ticketing #fuming #noloyalty #joke #notimpressed",0.873],["I dislike people who get offended by the littlest shit .",0.729],["I need a 🍱sushi date🍙 @AnzalduaG 🍝an olive guarded date🧀 @lexiereid369 and a 👊🏼Rockys date🍕 #tiff",0.354],["Forever angry that gh ruined Molly and morgan's bond\u002ffriendship #bitter",0.625],["@CrayonToCrayon @SueScoby \\nIt's always fun to anger 'All the Old Dudes.' with Rock N' Roll :))",0.354],["So my Indian Uber driver just called someone the N word. If I wasn't in a moving vehicle I'd have jumped out #disgusted #offended",0.729],["@kitanoye Hell is hot and boiling, isi ewu",0.458],["... flat party and I instantly get bollocked about it. ",0.542],["@ggreenwald Smh, remove ideologically bankrupt and opportunistic establishment now. They're burning all bridges and social contracts. ",0.521],["streets of rage 2 was hard to find for a while and then Itunes stepped in and the guys doing the vinyl \\nmade it so simple",0.458],["@trendykittykat Some people would rather hang on to their indignant anger. *weary sigh*",0.479],["@rumanaa_r @DaiIyRoasts what did I do to offend you? 🙄😭😂",0.396],["@SunandBeachBum 'you people' infuriate me!",0.792],["@AuntieSupreme @KimberlyCarole y'all found me to express yalls displeasure. 😉",0.438],["I'm not saying he might be like big foot but it might be like natural biological father says blood boiling if he cross",0. ...

# %% [markdown]
# We can see that even with Gemini's embeddings there doesn't seem to be a clear 2D separation of clusters with our data classes. It could be because emotions are often not discrete. Texts can contain mixed feelings (e.g., "bittersweet") or use similar language to express different emotions, causing their embeddings to be naturally close in semantic space. And also the process of projecting high-dimensional embeddings down to a 2D visualization inevitably loses some information, which can make distinct clusters appear to overlap.

# %% [markdown]
# ---
# ##### **>>> Exercise 4 (Take home):**
#
# Apply UMAP to the same embeddings to reduce the dimensionality to 3D vectors and plot the 3D graph, discuss the differences and similarities with the 2D graph.

# %%
import umap
import pandas as pd
import plotly.express as px

# 3D UMAP
reducer_3d = umap.UMAP(
    n_components=3, # 3D
    metric='cosine',
    random_state=28
)
embedding_3d = reducer_3d.fit_transform(X_embeddings)

df_plot_3d = pd.DataFrame(embedding_3d, columns=['UMAP1', 'UMAP2', 'UMAP3'])
df_plot_3d['emotion'] = combined_df['emotion'].values
df_plot_3d['intensity'] = combined_df['intensity'].values
df_plot_3d['text'] = combined_df['text'].values

fig_3d = px.scatter_3d(
    df_plot_3d,
    x='UMAP1',
    y='UMAP2',
    z='UMAP3',
    color='emotion',
    hover_data=['text', 'intensity'],
    title='3D UMAP Projection of Text Embeddings'
)

fig_3d.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="3190a6a9-6cb2-4fdd-aba2-0417b8bd72ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3190a6a9-6cb2-4fdd-aba2-0417b8bd72ba")) {                    Plotly.newPlot(                        "3190a6a9-6cb2-4fdd-aba2-0417b8bd72ba",                        [{"customdata":[["@ManUtd you have had from me over the years is irrelevant. Its an absolute joke. #manutd #ticketing  #noloyalty #joke #notimpressed",0.667],["When anger rises, think of the consequences. #quote #wisdom #anger",0.433],["Projection is perception. See it in someone else? You also at some level have that within you. #anger #worry",0.417],["All hell is breaking loose in Charlotte. #CharlotteProtest  #looting",0.625],["straight people are canoodling on the quad and I'm ",0.417],["@kingcharles9th i Lowkey forgot you had twitter and if you don't follow me back im gonna be #offended",0.421],["Sorry to burst your bubble but it isn't that century anymore. Welcome to the 21st century.",0.354],["@ThomsonCares Sam- yes we have! Not helpful at all! We need this sorting ASAP! You keep promising stuff that doesn't happen!!!! #fuming",0.771],["@CBSBigBrother never bring back Meech and Bridgette. Crying because someone looks at you? Ugh, and Bridgette. ",0.479],["@sueblue35 @nsoz7 @immortalbulldog huh? We have a sprint coach? We're the slowest team in the comp. Talk about robbing a living. ",0.292],["If my luck the rest of Fall goes anything like today, I think I'm going to like this season. #bestdayever #magic #work ",0.375],["@TzumiXIV huff puff",0.519],["@paulbushnell25 @EE bad news if ordered online it hasn't gone through same happened to me had to re order on the phone #furious",0.844],["@RealBD_ @ReyesAverie 47 unarmed blacks killed by white cops in 2015. That many die every month in Chicago wheres the #outrage",0.646],["Why a puerto Rican with Taino hair and a black nose gotta ruffle your targeted feathers?",0.5],["Ok but I just got called a 'White Devil' on the train and I didnt know whether to laugh or be offended",0.484],["@BIGGKATZ BUT arms (focused rage) is overpowered, it will be getting nerfed. It'll still be stronger than fury though",0.468],["@ManUtd you have had from me over the years is irrelevant. Its an absolute joke. #manutd #ticketing #fuming #noloyalty #joke #notimpressed",0.873],["I dislike people who get offended by the littlest shit .",0.729],["I need a 🍱sushi date🍙 @AnzalduaG 🍝an olive guarded date🧀 @lexiereid369 and a 👊🏼Rockys date🍕 #tiff",0.354],["Forever angry that gh ruined Molly and morgan's bond\u002ffriendship #bitter",0.625],["@CrayonToCrayon @SueScoby \\nIt's always fun to anger 'All the Old Dudes.' with Rock N' Roll :))",0.354],["So my Indian Uber driver just called someone the N word. If I wasn't in a moving vehicle I'd have jumped out #disgusted #offended",0.729],["@kitanoye Hell is hot and boiling, isi ewu",0.458],["... flat party and I instantly get bollocked about it. ",0.542],["@ggreenwald Smh, remove ideologically bankrupt and opportunistic establishment now. They're burning all bridges and social contracts. ",0.521],["streets of rage 2 was hard to find for a while and then Itunes stepped in and the guys doing the vinyl \\nmade it so simple",0.458],["@trendykittykat Some people would rather hang on to their indignant anger. *weary sigh*",0.479],["@rumanaa_r @DaiIyRoasts what did I do to offend you? 🙄😭😂",0.396],["@SunandBeachBum 'you people' infuriate me!",0.792],["@AuntieSupreme @KimberlyCarole y'all found me to express yalls displeasure. 😉",0.438],["I'm not saying he might be like big foot but it might be like natural biological father says blood boiling if he cross",0. ...

# %%
# Both 2D and 3D UMAP showed overlapping; the 3D plot preserves the same overall structure but adds slight layering along the third axis, giving a bit clearer local separation while still reflecting a continuous semantic spectrum rather than four distinct clusters.

# %% [markdown]
# ---
# ### **2.5 Retrieval-Augmented Generation (RAG)**
#
# `NOTE: This whole section including the exercise is now considered a bonus section, not counted for the main grade.`
#
# RAG (Retrieval-Augmented Generation) is a technique where a language model combines document retrieval with text generation. In RAG, a retrieval system first finds relevant documents or text chunks, and then the language model uses this retrieved information to generate a more informed and accurate response. This method enhances the model's ability to answer questions by grounding its responses in real, external data.
#
# In the following code, we will load a webpage as a document, which allows us to retrieve text from a URL. After loading the content, we will split the document into smaller, manageable chunks, making it easier for our model to process. Then, we'll generate embeddings for these chunks with a specified LLM model (Gemini Embedding Model). These embeddings will be stored in a vector database, which enables us to perform similarity searches. By setting up this retrieval system, we can use a RAG chain to answer questions. The retriever finds relevant text chunks from the document based on a query, and the LLM generates a response by incorporating this retrieved information, making the answers more grounded and accurate.
#
# In this example we use the library langchain, for documentation on more functions of the library you can check the following link: [LangChain Tutorials](https://python.langchain.com/docs/tutorials/)

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# Function to load, split, and retrieve documents
def load_and_retrieve_docs(url):
    loader = WebBaseLoader(
        web_paths=(url,),
        bs_kwargs=dict()
    )
    docs = loader.load() #We will load the URL that will serve as our data source
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150) #We will divide the URL in chunks of text for easier comparison in the vector space
    splits = text_splitter.split_documents(docs)
    #print(splits) #You can print this to see how the chunks in the url where split
    embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")
    vectorstore = Chroma.from_documents(documents=splits, embedding=embeddings) #Our vector space for comparison
    return vectorstore.as_retriever()


def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs) #Format the retrieved docs in an orderly manner for prompting

# Define the Gemini LLM function
def gemini_llm(question, context):
    system_prompt = "You are a RAG Agent that needs to provide a well structured answer based on the provided question and context."
    formatted_prompt = f"Question: {question}\n\nContext: {context}"
    response, logs = prompt_gemini(input_prompt = formatted_prompt, system_instruction = system_prompt, with_tokens_info = True)
    print(f"logs: \n{logs}")
    # print(f"Retrieved context: \n{context}\n\n") # You can print this to observe the retrieved context
    return response


# Define the RAG chain
def rag_chain(question, retriever):
    retrieved_docs = retriever.invoke(question)
    formatted_context = format_docs(retrieved_docs)
    return gemini_llm(question, formatted_context)
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
url="https://qbotica.com/understanding-artificial-general-intelligence-agi-an-in-depth-overview/"
# Create the retriever
retriever = load_and_retrieve_docs(url)

# Use the RAG chain
result = rag_chain(question="What are the Key Challenges in Realizing AGI’s Full Potential", retriever=retriever)
display(Markdown(result))
# Out:
# logs:
# {'model': 'gemini-2.5-flash-lite', 'input_tokens': 726, 'output_tokens': 190}
# The key challenges in realizing AGI's full potential stem from its fundamental requirements and the ethical considerations surrounding its development. These include:
#
# *   **Learning from Diverse Data:** Unlike narrow AI, which is trained on structured data, AGI needs to learn from a wide variety of unstructured data sources.
# *   **Computational Power:** The sheer amount of computational resources needed to process and learn from these vast and diverse datasets presents a significant hurdle.
# *   **Ethical Concerns:** Developing AGI responsibly requires addressing critical ethical issues such as:
#     *   **Bias and Fairness:** Ensuring algorithms are unbiased and treat everyone equally by training on diverse datasets and continuously monitoring performance.
#     *   **Privacy:** Prioritizing user data protection through robust privacy measures and transparent data usage policies.
#     *   **Accountability:** Establishing clear guidelines and legal frameworks to determine responsibility for decisions made by AGI systems and address any harm caused.

# %% [markdown]
# ##### **Actual answer in the URL:**
#
# ![pic11.png](https://drive.google.com/uc?export=view&id=1M1b6pA2zqbmZ7R9IihPLoIb-0zHX8O3v)
#
# ##### **Content in the URL that might get into the generated answer because of similar semantic meaning:**
#
# ![pic12.png](https://drive.google.com/uc?export=view&id=17MO1suYVBAhCBCGEolzgkz7kWwn0bUEx)
#
# source: https://qbotica.com/understanding-artificial-general-intelligence-agi-an-in-depth-overview/

# %% [markdown]
# ---
# ##### **>>> Bonus Exercise 5 (Take home):**
#
# `NOTE: This exercise is now considered a bonus one, not counted for the main grade, only as extra points.`
#
# Your task is to test the RAG system with your own chosen URL and analyze its performance.
#
# 1. Find a URL of a webpage with interesting text content to test the RAG pipeline.
# 2. Make a question about the content in the webpage you chose.
# 3. Discuss how good the question was answered by the model, if the model missed important information related to your question.
# 4. Display a screenshot of the real answer in the webpage.

# %%
# Business Judgment Rule (BJR)
url_bjr = "https://www.garciagurney.com/blog/understanding-the-business-judgment-rule/"

# Retriever of BJR
retriever_bjr = load_and_retrieve_docs(url_bjr)

# Use the RAG chain
result_bjr = rag_chain(question="What is Business Judgment Rule?", retriever=retriever_bjr)
display(Markdown(result_bjr))
# Out:
# logs:
# {'model': 'gemini-2.5-flash-lite', 'input_tokens': 523, 'output_tokens': 341}
# The Business Judgment Rule (BJR) is a legal principle that offers protection to corporate directors accused of breaching their fiduciary duty to the corporation, thereby causing harm. It essentially means that courts will generally respect the decisions made by directors if they can demonstrate that these decisions were:
#
# *   **Made in good faith.**
# *   **Exercised with the same level of care a prudent person would use.**
# *   **Based on the reasonable belief that the decisions were in the best interests of the corporation.**
#
# The BJR acknowledges that business decisions inherently involve risks and that directors cannot guarantee positive outcomes. This rule applies to various corporate decisions, such as mergers, acquisitions, product development, executive compensation, and strategic planning, providing directors with a "safe harbor" to make informed choices without the constant fear of personal liability. This, in turn, encourages a more proactive and entrepreneurial management style.
#
# However, the BJR is not absolute. A plaintiff can challenge its protection by providing evidence of:
#
# *   **Waste:** Decisions that result in the dissipation of corporate assets, like overpaying for goods or services, or excessive executive compensation.
# *   **Fraud:** Deceptive or misleading conduct intended to benefit the director or others at the corporation's or shareholders' expense.
# *   **Self-dealing:** Transactions where directors have a personal financial interest in the other party involved.
# *   **Gross negligence:** Failing to consider significant, easily discoverable facts that could negatively impact the corporation.
#
# If a director is found to have engaged in any of these actions, they may be held personally liable for the resulting harm, potentially facing consequences such as monetary damages or disgorgement of profits.

# %% [markdown]
# ##### **Actual answer in the URL:**
# ![BJR_real.png](https://drive.google.com/uc?id=12AHOqTdLqvceLt8xUtEA1UmwcbkPAfj_)

# %% [markdown]
# ---
# ### **2.6 Few-Shot Prompting Classification:**
#
# Few-shot prompting is a technique where a Large Language Model (LLM) is given a small number of labeled examples within a prompt to guide its classification. This allows the model to perform a new task with minimal data, avoiding the need for extensive fine-tuning.
#
# In this lab, we will use the Gemini API to perform zero-shot, 1-shot, and 5-shot emotion classification:
#
# *   **Zero-shot:** The model classifies text without any prior examples.
# *   **1-shot:** The model is given one example for each emotion before classifying.
# *   **5-shot:** The model is given five examples per emotion for better context.
#
# To make our implementation robust and efficient, we are incorporating two key features:
#
# 1.  **Structured Output:** We provide the Gemini model with a specific output schema (`Emotions` class). This instructs the model to return *only* a valid emotion label (e.g., `joy`), which makes the output predictable and reliable, minimizing errors.
# 2.  **API Rate Handling:** The code includes a function to manage the requests-per-minute limit of the Gemini API.
#
# We will test the model's performance on a small sample of 20 texts per emotion to ensure the process runs quickly. If the model provides an invalid response, the code will automatically retry the request until a valid classification is received.
#
# **Prompt Structure:**
# `System Instruction -> Task Description -> Examples (if not zero-shot) -> Text to Classify`
#
#
# <span style="color:green">For the exercises in this section there is no need to re-run the cells, you can use the data that has been saved previously to the corresponding directory.</span>

# %%
# Funciton for visualizing confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix',
                          cmap=sns.cubehelix_palette(as_cmap=True)):
    """
    This function is modified from:
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    """
    classes.sort()
    tick_marks = np.arange(len(classes))

    fig, ax = plt.subplots(figsize=(5,5))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels = classes,
           yticklabels = classes,
           title = title,
           xlabel = 'Predicted label',
           ylabel = 'True label')

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    ylim_top = len(classes) - 0.5
    plt.ylim([ylim_top, -.5])
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import enum
import os
from tqdm import tqdm
import json
import time
# Define the emotion labels
emotions = ['anger', 'fear', 'joy', 'sadness']
# Define the model to use for few-shot prompting

# Schema for the output, the type enum can be used to make a pool of options if what we want is to classify our text selecting only one of them
class Emotions(enum.StrEnum):
    ANGER = 'anger'
    FEAR = 'fear'
    JOY = 'joy'
    SADNESS = 'sadness'


# Function to handle the rate limits of gemini models
def handle_rate_limit(request_count, first_request_time, max_calls_per_min):
    current_time = time.time()

    # Initialize timer on the first request of a new window
    if request_count == 0:
        first_request_time = current_time

    request_count += 1

    # If the rate limit is reached
    if request_count > max_calls_per_min:
        elapsed_time = current_time - first_request_time
        if elapsed_time < 60:
            wait_time = 60 - elapsed_time
            print(f"Rate limit of {max_calls_per_min} requests per minute reached. Waiting for {wait_time:.2f} seconds.")
            time.sleep(wait_time)

        # Reset for the new window
        request_count = 1
        first_request_time = time.time()

    return request_count, first_request_time, max_calls_per_min

# Function to sample examples per emotion category
def sample_few_shots(df, emotions, num_samples=5):
    few_shot_examples = {}
    for emotion in emotions:
        few_shot_examples[emotion] = df[df['emotion'] == emotion].sample(n=num_samples, random_state=42)
    return few_shot_examples

# Function to build the prompt based on the number of examples (few-shot, 1-shot, zero-shot)
def build_prompt(examples, emotions, num_shots=5):
    classification_instructions = """
You will be given a text extracted from social media and your task is to classify the text into one of the following emotion categories:
"anger" | "fear" | "joy" | "sadness"
    """

    prompt = classification_instructions + "\n\n"

    if num_shots > 0:
        prompt += f"Examples: \n"
        for emotion in emotions:
            for _, row in examples[emotion].iterrows():
                prompt += f"Text: {row['text']}\nClass: {emotion}\n\n" #Show the examples in the same format it will be shown for the classification text
                if num_shots == 1:  # If 1-shot, break after the first example for each emotion
                    break
    return prompt

# Function to classify using the LLM with retry for incorrect responses
def classify_with_llm(test_text, prompt_base, system_prompt, classes, schema):
    response = None
    while not response or response not in classes:
        full_prompt = f"{prompt_base}\nClassification:\nText: {test_text}\nClass: " #The classification text will leave the emotion label to be filled in by the LLM
        try:
            result = prompt_gemini(input_prompt = [full_prompt], schema = schema, system_instruction = system_prompt)
            # print(f"result: {result} \n")
            # print(f"type: {type(result)}")
            if not result:
                # In case of giving empty responses with temperature 0.0, we set a higher temperature to seek for different responses
                result = prompt_gemini(input_prompt = [full_prompt], schema = schema, system_instruction = system_prompt, temperature=1.0)

            try:
                # If the result is in the correct format it can be parsed using json
                response = json.load(result)
            except:
                # In case it's not in a json friendly format
                # Deleting characters " and ' in case they appear in our response with the class of the text
                response = result.replace('"', '')
                response = response.replace("'", "")


        # except exceptions.ResourceExhausted as e:
        except Exception as e:
            print(f"Waiting to retry... Error: {e}")
            time.sleep(15)
            print(f"test_text: {test_text}")
            return classify_with_llm(test_text, prompt_base, system_prompt, classes, schema) # Retry the request


        if response not in classes:  # Retry if not a valid response
            print(f"Invalid response: {response}. Asking for reclassification.")
    return response

# Main function to run the experiment with the option for zero-shot, 1-shot, or 5-shot prompting
def run_experiment(df_train, df_test, num_test_samples=5, num_shots=5):
    # Sample examples for few-shot prompting based on num_shots
    if num_shots > 0:
        few_shot_examples = sample_few_shots(df_train, emotions, num_samples=num_shots)
        prompt_base = build_prompt(few_shot_examples, emotions, num_shots=num_shots)
    else:
        prompt_base = build_prompt(None, emotions, num_shots=0)  # Zero-shot has no examples

    # System prompt for our classification model:
    system_prompt = "You are an emotion classification model for text data. Do not give empty responses, classify according to the list of possible classes."

    # Prepare to classify the test set
    results_data = []

    print(prompt_base)
    # Sample 20 examples per emotion for the test set to classify
    test_samples = sample_few_shots(df_test, emotions, num_samples=num_test_samples)

    # Variables to handle rate limit of gemini
    request_count = 0
    max_calls_per_min = 15 # Gemini 2.5 Flash Lite has this maximum set in the documentation
    first_request_time = None

    # Classify 20 test examples (5 from each category) and save predictions
    for emotion in emotions:
        for _, test_row in tqdm(test_samples[emotion].iterrows(), desc=f"Processing samples for emotion: {emotion}...", total=num_test_samples):
            test_text = test_row['text']
            request_count, first_request_time, max_calls_per_min = handle_rate_limit(request_count, first_request_time, max_calls_per_min)  # Check and handle rate limit before each API call
            predicted_emotion = classify_with_llm(test_text = test_text, prompt_base = prompt_base, system_prompt = system_prompt, classes = emotions, schema = Emotions)
            # Append the results data:
            results_data.append({
                    'text': test_text,
                    'true_emotion': emotion,
                    'predicted_emotion': predicted_emotion
                })

    # Create dataframe to save the results data
    results_df = pd.DataFrame(results_data)

    # Extract just the true and predicted labels for metrics calculations
    true_labels = results_df['true_emotion']
    predictions = results_df['predicted_emotion']

    output_dir = "./DM2025-Lab2-Exercise/results/llm_classification_results"
    os.makedirs(output_dir, exist_ok=True)
    # Save the results
    filename = f"{output_dir}/results_samples_{num_test_samples}_shots_{num_shots}.csv"

    # Save the DataFrame to CSV
    results_df.to_csv(filename, index=False)
    print(f"\nResults saved to {filename}")

    # Calculate accuracy
    accuracy = accuracy_score(true_labels, predictions)
    print(f"Accuracy: {accuracy * 100:.2f}%")

    # Classification report
    print(classification_report(y_true=true_labels, y_pred=predictions))

    # Plot confusion matrix
    cm = confusion_matrix(y_true=true_labels, y_pred=predictions)
    my_tags = ['anger', 'fear', 'joy', 'sadness']
    plot_confusion_matrix(cm, classes=my_tags, title=f'Confusion matrix for classification with \n{num_shots}-shot prompting')

# %% [markdown]
# **Important: The next part should take around 16 minutes to finish running due to API Rate Limits**
#
# **Note:** You might see an `429 RESOURCE_EXHAUSTED` error when running the following code all at once, this is because the `current API Rate Limit handling cannot reliably find out how many requests we have left per minute` from cell to cell, there is no Gemini feature created for it to get the information from their servers. So, `if you don't want to see the error you can just wait 1 minute` after one cell finished processing. But `even if there is an error showing it is fine`, internally in the code `there is a retry that happens every 15 seconds` until we finish processing our sampled data. `The lab is designed to never reach the total rate limit per day quota.`

# %%
# If you see '429 RESOURCE_EXHAUSTED' errors it's fine, wait until the data gets processed, it will keep retrying until it finishes

# Example of running the experiment with zero-shot prompting
run_experiment(train_df, test_df, num_test_samples=20, num_shots=0)
# Out:
# You will be given a text extracted from social media and your task is to classify the text into one of the following emotion categories:
# "anger" | "fear" | "joy" | "sadness"
# Processing samples for emotion: anger...:  70%|███████   | 14/20 [00:09<00:03,  1.66it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 15.033006979s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '15s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 15.004138067s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '15s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: I think our defense here at USC is playing well, we just need to fix a few things on offense and we can win the PAC 12 this year'
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 59.957426886s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '59s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 59.93486466s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '59s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: I think our defense here at USC is playing well, we just need to fix a few things on offense and we can win the PAC 12 this year'
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 44.896363349s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '44s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 44.869067327s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '44s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: I think our defense here at USC is playing well, we just need to fix a few things on offense and we can win the PAC 12 this year'
# Processing samples for emotion: anger...:  75%|███████▌  | 15/20 [00:55<01:11, 14.29s/it]
# Rate limit of 15 requests per minute reached. Waiting for 4.89 seconds.
# Processing samples for emotion: anger...: 100%|██████████| 20/20 [01:03<00:00,  3.19s/it]
# Processing samples for emotion: fear...:  50%|█████     | 10/20 [00:06<00:07,  1.42it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.71 seconds.
# Processing samples for emotion: fear...: 100%|██████████| 20/20 [01:03<00:00,  3.16s/it]
# Processing samples for emotion: joy...:  25%|██▌       | 5/20 [00:03<00:09,  1.66it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.79 seconds.
# Processing samples for emotion: joy...: 100%|██████████| 20/20 [01:05<00:00,  3.26s/it]
# Processing samples for emotion: sadness...:   0%|          | 0/20 [00:00<?, ?it/s]
# Rate limit of 15 requests per minute reached. Waiting for 47.89 seconds.
# Processing samples for emotion: sadness...:  75%|███████▌  | 15/20 [01:01<00:04,  1.05it/s]
# Rate limit of 15 requests per minute reached. Waiting for 46.75 seconds.
# Processing samples for emotion: sadness...: 100%|██████████| 20/20 [01:52<00:00,  5.62s/it]
# Results saved to ./DM2025-Lab2-Exercise/results/llm_classification_results/results_samples_20_shots_0.csv
# Accuracy: 51.25%
#               precision    recall  f1-score   support
#
#        anger       0.42      0.65      0.51        20
#         fear       0.71      0.25      0.37        20
#          joy       0.48      0.70      0.57        20
#      sadness       0.69      0.45      0.55        20
#
#     accuracy                           0.51        80
#    macro avg       0.58      0.51      0.50        80
# weighted avg       0.58      0.51      0.50        80

# %%
# If you see '429 RESOURCE_EXHAUSTED' errors it's fine, wait until the data gets processed, it will keep retrying until it finishes

# Example of running the experiment with 1-shot prompting
run_experiment(train_df, test_df, num_test_samples=20, num_shots=1)
# Out:
# You will be given a text extracted from social media and your task is to classify the text into one of the following emotion categories:
# "anger" | "fear" | "joy" | "sadness"
#
#
# Examples:
# Text: Some moving clips on youtube tonight of the vigil held at Tulsa Metropolitan Baptist church for #TerenceCruther #justice #anger #sadness
# Class: anger
#
# Text: I have learned over the years that when one's mind is made up, this diminishes fear. –Rosa Parks #quotes #motivation
# Class: fear
#
# Text: Look forward to the detours because they bring delightful surprises. #lifequote #delight
# Class: joy
#
# Text: Isaiah 40:31\nthose who trust in the Lord will find new strength.\nThey will soar high on wings like eagles.\nThey will run and not grow weary.
# Class: sadness
# Processing samples for emotion: anger...:  55%|█████▌    | 11/20 [00:08<00:06,  1.33it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 10.90383384s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '10s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 10.877793993s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '10s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Anger, resentment, and hatred are the destroyer of your fortune today.
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 55.836280643s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '55s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 55.814376987s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '55s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Anger, resentment, and hatred are the destroyer of your fortune today.
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 40.768535537s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '40s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 40.745685246s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '40s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Anger, resentment, and hatred are the destroyer of your fortune today.
# Processing samples for emotion: anger...:  75%|███████▌  | 15/20 [00:57<00:27,  5.54s/it]
# Rate limit of 15 requests per minute reached. Waiting for 2.78 seconds.
# Processing samples for emotion: anger...: 100%|██████████| 20/20 [01:03<00:00,  3.18s/it]
# Processing samples for emotion: fear...:  35%|███▌      | 7/20 [00:05<00:09,  1.40it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 10.488904213s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '10s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 10.464097371s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '10s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Honestly, there are some awful people on the internet... smh...
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 55.416132816s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '55s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 55.386106175s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '55s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Honestly, there are some awful people on the internet... smh...
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 40.348519573s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '40s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 40.324500112s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '40s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Honestly, there are some awful people on the internet... smh...
# Processing samples for emotion: fear...:  50%|█████     | 10/20 [00:52<01:15,  7.55s/it]
# Rate limit of 15 requests per minute reached. Waiting for 3.82 seconds.
# Processing samples for emotion: fear...: 100%|██████████| 20/20 [01:03<00:00,  3.17s/it]
# Processing samples for emotion: joy...:  15%|█▌        | 3/20 [00:01<00:11,  1.54it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 10.217320836s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '10s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 10.191280666s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '10s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: If any trump supporters and Hillary haters wanna chirp some weak minded, pandering liberals just tweet at @EmmyA2 @snickerfritz04
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 55.157376903s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '55s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 55.134059251s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '55s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: If any trump supporters and Hillary haters wanna chirp some weak minded, pandering liberals just tweet at @EmmyA2 @snickerfritz04
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 40.094817756s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '40s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 40.069192293s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '40s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: If any trump supporters and Hillary haters wanna chirp some weak minded, pandering liberals just tweet at @EmmyA2 @snickerfritz04
# Processing samples for emotion: joy...:  25%|██▌       | 5/20 [00:49<03:03, 12.24s/it]
# Rate limit of 15 requests per minute reached. Waiting for 3.80 seconds.
# Processing samples for emotion: joy...:  95%|█████████▌| 19/20 [01:02<00:00,  1.32it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 9.698772021s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '9s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 9.672405526s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '9s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: @tomlinmayniac starting my new challenge ! A glee poll every day !
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 54.620666954s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '54s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 54.592836592s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '54s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: @tomlinmayniac starting my new challenge ! A glee poll every day !
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 39.552330499s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '39s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 39.5267658s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '39s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: @tomlinmayniac starting my new challenge ! A glee poll every day !
# Processing samples for emotion: joy...: 100%|██████████| 20/20 [01:48<00:00,  5.43s/it]
# Processing samples for emotion: sadness...:   0%|          | 0/20 [00:00<?, ?it/s]
# Rate limit of 15 requests per minute reached. Waiting for 4.33 seconds.
# Processing samples for emotion: sadness...:  75%|███████▌  | 15/20 [00:14<00:03,  1.50it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.65 seconds.
# Processing samples for emotion: sadness...: 100%|██████████| 20/20 [01:08<00:00,  3.41s/it]
# Results saved to ./DM2025-Lab2-Exercise/results/llm_classification_results/results_samples_20_shots_1.csv
# Accuracy: 57.50%
#               precision    recall  f1-score   support
#
#        anger       0.45      0.70      0.55        20
#         fear       0.67      0.30      0.41        20
#          joy       0.58      0.70      0.64        20
#      sadness       0.75      0.60      0.67        20
#
#     accuracy                           0.57        80
#    macro avg       0.61      0.57      0.57        80
# weighted avg       0.61      0.57      0.57        80

# %%
# If you see '429 RESOURCE_EXHAUSTED' errors it's fine, wait until the data gets processed, it will keep retrying until it finishes

# Example of running the experiment with 5-shot prompting
run_experiment(train_df, test_df, num_test_samples=20, num_shots=5)
# Out:
# You will be given a text extracted from social media and your task is to classify the text into one of the following emotion categories:
# "anger" | "fear" | "joy" | "sadness"
#
#
# Examples:
# Text: Some moving clips on youtube tonight of the vigil held at Tulsa Metropolitan Baptist church for #TerenceCruther #justice #anger #sadness
# Class: anger
#
# Text: my momma irritate me asking all these questions like gone 😤
# Class: anger
#
# Text: #firsttweetever sippin #hotchocolate wondering #why I finally gave in &lt;3 haha #hellloooootwitter - ...its because #facebookisforfamily
# Class: anger
#
# Text: @CI  I don't think Monalisa has respect for anyone but herself! I think she'll ruffle a few feathers. #TheJail
# Class: anger
#
# Text: I screened my own snap what kind of narcissistic ass would smh
# Class: anger
#
# Text: I have learned over the years that when one's mind is made up, this diminishes fear. –Rosa Parks #quotes #motivation
# Class: fear
#
# Text: @SportsTraderIT Madrid is playing awful and no modric but 90 minutes in Bernabéu stadium are so so long. Viallreal never won there
# Class: fear
#
# Text: ok, ok.. I know.. my last tweet was #terrible
# Class: fear
#
# Text: @leeuwlion 'The furries are restless tonight'.
# Class: fear
#
# Text: Jeans with fake pockets
# Class: fear
#
# Text: Look forward to the detours because they bring delightful surprises. #lifequote #delight
# Class: joy
#
# Text: @my2k aaa Cam animated that, so proud of our boy
# Class: joy
#
# Text: For a moment I found myself smiling
# Class: joy
#
# Text: @govph I would like to know about the source of The President's optimism about running the country. I wonder if he can answer my curiosity.
# Class: joy
#
# Text: One time I saw Rachel from glee tell someone their job was on a pole and I said that in 5th grade to a boy and he look confused
# Class: joy
#
# Text: Isaiah 40:31\nthose who trust in the Lord will find new strength.\nThey will soar high on wings like eagles.\nThey will run and not grow weary.
# Class: sadness
#
# Text: History repeating itself..GAA is our culture how dare anyone think it's ok to discourage any Irish person from attending any match or final
# Class: sadness
#
# Text: @AerLingus #business class #Los Angeles to Dublin #destroyed luggage #60 day customer response time #unhappy customer
# Class: sadness
#
# Text: @everton_de_leon @sterushton Genuinely grim stuff. Over a century of history sold off by some porn baron twats for a minty new stadium. Urgh
# Class: sadness
#
# Text: Im really constipated. This is depressing
# Class: sadness
# Processing samples for emotion: anger...:  55%|█████▌    | 11/20 [00:07<00:05,  1.65it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 7.9342909s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '7s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 7.908358436s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '7s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Anger, resentment, and hatred are the destroyer of your fortune today.
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 52.868079338s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '52s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 52.846756042s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '52s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Anger, resentment, and hatred are the destroyer of your fortune today.
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 37.816700935s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '37s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 37.797078529s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '37s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Anger, resentment, and hatred are the destroyer of your fortune today.
# Processing samples for emotion: anger...:  75%|███████▌  | 15/20 [00:54<00:26,  5.22s/it]
# Rate limit of 15 requests per minute reached. Waiting for 5.41 seconds.
# Processing samples for emotion: anger...: 100%|██████████| 20/20 [01:02<00:00,  3.14s/it]
# Processing samples for emotion: fear...:  35%|███▌      | 7/20 [00:04<00:08,  1.45it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 7.408440702s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '7s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 7.374855747s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '7s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Honestly, there are some awful people on the internet... smh...
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 52.331783248s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '52s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 52.307619001s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '52s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Honestly, there are some awful people on the internet... smh...
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 37.270803527s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '37s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 37.235102521s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '37s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Honestly, there are some awful people on the internet... smh...
# Processing samples for emotion: fear...:  50%|█████     | 10/20 [00:52<01:15,  7.55s/it]
# Rate limit of 15 requests per minute reached. Waiting for 4.83 seconds.
# Processing samples for emotion: fear...: 100%|██████████| 20/20 [01:03<00:00,  3.20s/it]
# Processing samples for emotion: joy...:  15%|█▌        | 3/20 [00:02<00:12,  1.33it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 6.075178645s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 6.039483362s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: If any trump supporters and Hillary haters wanna chirp some weak minded, pandering liberals just tweet at @EmmyA2 @snickerfritz04
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 50.998431701s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '50s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 50.964105185s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '50s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: If any trump supporters and Hillary haters wanna chirp some weak minded, pandering liberals just tweet at @EmmyA2 @snickerfritz04
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 35.924567843s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '35s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 35.894928648s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '35s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: If any trump supporters and Hillary haters wanna chirp some weak minded, pandering liberals just tweet at @EmmyA2 @snickerfritz04
# Processing samples for emotion: joy...:  25%|██▌       | 5/20 [00:49<03:02, 12.18s/it]
# Rate limit of 15 requests per minute reached. Waiting for 4.04 seconds.
# Processing samples for emotion: joy...:  95%|█████████▌| 19/20 [01:03<00:00,  1.14it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 4.776751104s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '4s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 4.740654071s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '4s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: @tomlinmayniac starting my new challenge ! A glee poll every day !
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 49.704225554s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '49s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 49.684145311s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '49s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: @tomlinmayniac starting my new challenge ! A glee poll every day !
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 34.650913138s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '34s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 34.621920332s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '34s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: @tomlinmayniac starting my new challenge ! A glee poll every day !
# Processing samples for emotion: joy...: 100%|██████████| 20/20 [01:49<00:00,  5.49s/it]
# Processing samples for emotion: sadness...:   0%|          | 0/20 [00:00<?, ?it/s]
# Rate limit of 15 requests per minute reached. Waiting for 3.45 seconds.
# Processing samples for emotion: sadness...:  75%|███████▌  | 15/20 [00:13<00:03,  1.44it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.91 seconds.
# Processing samples for emotion: sadness...: 100%|██████████| 20/20 [01:07<00:00,  3.37s/it]
# Results saved to ./DM2025-Lab2-Exercise/results/llm_classification_results/results_samples_20_shots_5.csv
# Accuracy: 56.25%
#               precision    recall  f1-score   support
#
#        anger       0.50      0.65      0.57        20
#         fear       0.62      0.40      0.48        20
#          joy       0.59      0.65      0.62        20
#      sadness       0.58      0.55      0.56        20
#
#     accuracy                           0.56        80
#    macro avg       0.57      0.56      0.56        80
# weighted avg       0.57      0.56      0.56        80

# %% [markdown]
# ---
# ##### **>>> Exercise 6 (Take home):**
#
# Compare and discuss the overall results of the zero-shot, 1-shot and 5-shot classification.

# %%
# Overall Performance: Across the three attempts, the performance improves consistently as adding more shots (e.g., 0-shot: 51.25%⭢1-shot: 56.25%⭢5-shot: 62.50%), showing adding more shots may gain the stability of the model’s predictions.
# Single-Class Performances: Anger and Joy tend to be more stable in all attempts, since these classes are relatively easy for the model; Sadness and Fear then benefits from few-shot prompting.
# Reminder: As the number of shots increasing, there are still some tradeoffs existing in the model (e.g., the Joy class). These tradeoffs are likely to become more severe as the number of shots grows very large, potentially leading to diminishing returns or overfitting to the specific in-context examples.

# %% [markdown]
# ---
# ##### **>>> Exercise 7 (Take home):**
#
# **Case Study:** Check the results' files inside the `results/llm_classification_results` directory and find cases where the **text classification improves with more examples** (pred emotion is right with examples), **cases where it does not improve** (pred emotion always wrong) and **cases where the classification got worse with more examples** (pred emotion goes from right to wrong with examples). For this you need to load the results with pandas and handle the data using its dataframe functions. Discuss about the findings.

# %%
import pandas as pd

base_dir = "./DM2025-Lab2-Exercise/results/llm_classification_results"

df0 = pd.read_csv(f"{base_dir}/results_samples_20_shots_0.csv")
df1 = pd.read_csv(f"{base_dir}/results_samples_20_shots_1.csv")
df5 = pd.read_csv(f"{base_dir}/results_samples_20_shots_5.csv")

df0 = df0.rename(columns={"predicted_emotion": "pred_0"})
df1 = df1.rename(columns={"predicted_emotion": "pred_1"})
df5 = df5.rename(columns={"predicted_emotion": "pred_5"})

# %%
# Merge text, true_emotion and pred
merged = (
    df0[["text", "true_emotion", "pred_0"]]
    .merge(df1[["text", "true_emotion", "pred_1"]], on=["text", "true_emotion"], how="inner")
    .merge(df5[["text", "true_emotion", "pred_5"]], on=["text", "true_emotion"], how="inner")
)

merged["correct_0"] = merged["true_emotion"] == merged["pred_0"]
merged["correct_1"] = merged["true_emotion"] == merged["pred_1"]
merged["correct_5"] = merged["true_emotion"] == merged["pred_5"]

# %%
# Improved (False to True)
improved = merged[(merged["correct_0"] == False) & (merged["correct_5"] == True)]

print("Improved cases:", len(improved))
improved.head()
# Out:
# Improved cases: 7
#                                                  text true_emotion pred_0  \
# 16   @LeonWobYP b***er off. NCFC is a grudge match :)        anger    joy
# 24  The moment you bring her to meet your best fri...         fear    joy
# 26  Trying to book holiday flights on @britishairw...         fear  anger
# 36  Bout ta get my @dontbreathe on up in here! @Wa...         fear    joy
# 64  MC: what are you listen to these days?\nBogum:...      sadness    joy
#
#      pred_1   pred_5  correct_0  correct_1  correct_5
# 16    anger    anger      False       True       True
# 24     fear     fear      False       True       True
# 26    anger     fear      False      False       True
# 36      joy     fear      False      False       True
# 64  sadness  sadness      False       True       True

# %%
improved["true_emotion"].value_counts(normalize=True)
# Out:
# true_emotion
# fear       0.428571
# sadness    0.428571
# anger      0.142857
# Name: proportion, dtype: float64

# %%
# No_Improved (False still False)
no_improved = merged[
    (merged["correct_0"] == False) &
    (merged["correct_1"] == False) &
    (merged["correct_5"] == False)
]

print("No improvement cases:", len(no_improve))
no_improved.head()
# Out:
# No improvement cases: 31
#                                                  text true_emotion pred_0  \
# 7   Ok scrubbed hands 5 times before trying to put...        anger   fear
# 8      @__NETFLIXNCHILL I fuck with madden way harder        anger    joy
# 12  Kik to trade, have fun or a conversation  (kik...        anger    joy
# 14  I think our defense here at USC is playing wel...        anger    joy
# 17  @FluDino Event started! everyone is getting re...        anger    joy
#
#    pred_1 pred_5  correct_0  correct_1  correct_5
# 7    fear   fear      False      False      False
# 8     joy    joy      False      False      False
# 12    joy    joy      False      False      False
# 14    joy    joy      False      False      False
# 17    joy    joy      False      False      False

# %%
no_improved["true_emotion"].value_counts(normalize=True)
# Out:
# true_emotion
# fear       0.387097
# sadness    0.225806
# anger      0.193548
# joy        0.193548
# Name: proportion, dtype: float64

# %%
# Worse (True still False)
worse = merged[(merged["correct_0"] == True) & (merged["correct_5"] == False)]

print("Worse cases:", len(worse))
worse.head()
# Out:
# Worse cases: 3
#                                                  text true_emotion   pred_0  \
# 2   [ @HedgehogDylan ] *she would frown a bit, fol...        anger    anger
# 56  @GigaFag @pipertownsend_ snapchat new would be...          joy      joy
# 60  @Eeevah14 don't I know it, try not to fret my ...      sadness  sadness
#
#    pred_1 pred_5  correct_0  correct_1  correct_5
# 2   anger   fear       True       True      False
# 56    joy  anger       True       True      False
# 60   fear   fear       True      False      False

# %%
worse["true_emotion"].value_counts(normalize=True)
# Out:
# true_emotion
# anger      0.333333
# joy        0.333333
# sadness    0.333333
# Name: proportion, dtype: float64

# %%
# "Improved” cases where the 0-shot prediction was wrong but the 5-shot prediction became correct, “No_improved” cases where all three attempts remained incorrect, and “Worse” cases where the 0-shot prediction was correct but the 5-shot prediction turned incorrect.
# The results show that there are 7 improved cases (about 17%), mostly labeled as fear and sadness, suggesting that few-shot prompting particularly helps the model better recognize more subtle negative emotions that were initially misclassified as joy or anger. In contrast, 31 cases (about 76%) showed no improvement at all; these are often conversational or multi-emotion texts where correctly assigning a single label would require extra context. Finally, 3 cases (about 7%) actually got worse: they evenly spread across anger, joy, and sadness. This may reveal the issue of bias effect, where the small in-context sample nudges the model to overfit to certain lexical patterns and shift some borderline instances to the wrong class.
# Overall, the analysis confirms that few-shot prompting can rescue some difficult examples, especially for fear and sadness; but, it does not fix the ambiguous inputs and degrade the performance.

# %% [markdown]
# ---
# ### **2.7 Extra LLM Related Materials:**
# So this will be it for the lab, but here are some extra materials if you would like to explore:
#
# - **How to use OpenAI ChatGPT model's API (Not Free API):** [Basics Video](https://www.youtube.com/watch?v=e9P7FLi5Zy8), [Basics GitHub](https://github.com/gkamradt/langchain-tutorials/blob/main/chatapi/ChatAPI%20%2B%20LangChain%20Basics.ipynb), [RAG's Basics Video](https://www.youtube.com/watch?v=9AXP7tCI9PI&t=300s), [RAG's Basics GitHub](https://github.com/techleadhd/chatgpt-retrieval)
#
# - **Advanced topic - QLoRA (Quantized Low-Rank Adapter):** QLoRA is a method used to make fine-tuning large language models more efficient. It works by adding a small, trainable part (LoRA) to a pre-trained model, while keeping the rest of the model frozen. At the same time, it reduces the size of the model’s data using a process called quantization, which makes the model require less memory. This allows you to fine-tune large models without needing as much computational power, making it easier to adapt models for specific tasks. Materials: [Paper GitHub](https://github.com/artidoro/qlora?tab=readme-ov-file), [Llama 3 Application Video](https://www.youtube.com/watch?v=YJNbgusTSF0&t=512s),[Llama 3 Application GitHub](https://github.com/adidror005/youtube-videos/blob/main/LLAMA_3_Fine_Tuning_for_Sequence_Classification_Actual_Video.ipynb)
#
# - **How to Fine-tune and run local LLMs with the `unsloth` library:** [unsloth tutorials](https://docs.unsloth.ai/models/tutorials-how-to-fine-tune-and-run-llms)
#
# - **Google's Agent Development Kit Documentation:** [ADK](https://google.github.io/adk-docs/)
#
# - **Build AI agents with LangGraph:** [LangGraph Documentation](https://langchain-ai.github.io/langgraph/concepts/why-langgraph/)

# %% [markdown]
# ---
